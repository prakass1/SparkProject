# %% [markdown]
# ## IMDB Dataset Analysis with Apache Spark
#
# The Dataset of Imdb is analysed using apache spark and RDD(Resilent Distributed Dataset). There are two .tsv files.
# 1. Titles
# 2. Rating
#
# The dataset is downloaded from: https://www.imdb.com/interfaces/
#
# Titles: This tsv file contains all details related with the movies and is a massive dataset with 50M records.<br> Rating: This tsv file contains average rating of some movies.

# %%
import pyspark as ps
from pyspark import SparkContext,SparkConf
from pyspark.sql import SparkSession
from pyspark.sql.functions import desc
from pyspark.sql.functions import rand
from pyspark.sql import Row as row
import pandas as pd
from pyspark.mllib.classification import NaiveBayes, NaiveBayesModel
from pyspark.mllib.linalg import Vectors
from pyspark.mllib.regression import LabeledPoint
import matplotlib.pyplot as plt
import numpy
from pyspark.mllib.regression import LinearRegressionWithSGD
from pyspark.mllib.classification import SVMWithSGD,LogisticRegressionWithLBFGS
from pyspark.ml.evaluation import RegressionEvaluator

# %%
conf=SparkConf().setAppName("Imdb data Analysis")
spark = SparkSession.builder.appName('Imdb').getOrCreate()

# %%
titles = sc.textFile('/home/prakass1/imdb_dataset/data_title.tsv').cache()
rating = sc.textFile('/home/prakass1/imdb_dataset/data_rating.tsv').cache()

# %%
def parse_data(line):
    data = line.split('\t')
    line = row(movieId = str(data[0]), movieType=str(data[1]), movieName = str(data[2]), genre = str(data[8]),runningTime=str(data[7]))
    return line

# %%
def parse_rating(line):
    data = line.split('\t')
    line = row(movieId = str(data[0]), avgRating=float(data[1]), votes = int(data[2]))
    return line

# %%
def filter_header(data):
    header = data.first()
    data = data.filter(lambda line: line !=header)
    return data

# %%
def parse_rating_data(line):
    data = line.split('\t')
    row = data[0] + "," + data[1] + "," + data[2]
    return row

# %%
def perform_title_mapping(lines):
    rows = lines.map(parse_data)
    return rows

# %%
def perform_rating_mapping(lines):
    rows = lines.map(parse_rating)
    return rows

# %%
#Filter the first header (Assumption made that header is always the first row)
titles_rows = filter_header(titles)
rating_rows = filter_header(rating)

# %%
#Perform mapping for the rows of data
titles = perform_title_mapping(titles_rows)
rating = perform_rating_mapping(rating_rows)

# %%
titles.take(2)
# Out:
# [Row(genre='Documentary,Short', movieId='tt0000001', movieName='Carmencita', movieType='short', runningTime='1'),
#  Row(genre='Animation,Short', movieId='tt0000002', movieName='Le clown et ses chiens', movieType='short', runningTime='5')]

# %%
df_titles = spark.createDataFrame(titles)
df_rating = spark.createDataFrame(rating)

# %%
df_titles.describe().show()

# %%
#Partition Both RDD
df_titles.head(5)
# Out:
# [Row(genre='Documentary,Short', movieId='tt0000001', movieName='Carmencita', movieType='short', runningTime='1'),
#  Row(genre='Animation,Short', movieId='tt0000002', movieName='Le clown et ses chiens', movieType='short', runningTime='5'),
#  Row(genre='Animation,Comedy,Romance', movieId='tt0000003', movieName='Pauvre Pierrot', movieType='short', runningTime='4'),
#  Row(genre='Animation,Short', movieId='tt0000004', movieName='Un bon bock', movieType='short', runningTime='\\N'),
#  Row(genre='Short', movieId='tt0000005', movieName='Blacksmith Scene', movieType='short', runningTime='1')]

# %%
#Describe the data of Titles
df_titles.printSchema()
# Out:
# root
#  |-- genre: string (nullable = true)
#  |-- movieId: string (nullable = true)
#  |-- movieName: string (nullable = true)
#  |-- movieType: string (nullable = true)
#  |-- runningTime: string (nullable = true)

# %%
df_rating.head(5)
# Out:
# [Row(avgRating=5.8, movieId='tt0000001', votes=1382),
#  Row(avgRating=6.5, movieId='tt0000002', votes=161),
#  Row(avgRating=6.6, movieId='tt0000003', votes=960),
#  Row(avgRating=6.4, movieId='tt0000004', votes=97),
#  Row(avgRating=6.2, movieId='tt0000005', votes=1659)]

# %%
#Describe the data of Rating
df_rating.printSchema()
# Out:
# root
#  |-- avgRating: double (nullable = true)
#  |-- movieId: string (nullable = true)
#  |-- votes: long (nullable = true)

# %%
df_rating.count()
# Out:
# 838182

# %%
df_titles.count()
# Out:
# 5040244

# %%
#Order the rating in the descending order of rating
grouped_data = df_rating.orderBy(desc('votes'))

# %%
#Only get type as movie
cachedTitles = df_titles.filter(df_titles.movieType=='movie').select('movieId','movieName','genre').cache()
#cachedTitles.count()
cachedTitles.movieId
# Out:
# Column<b'movieId'>

# %%
#Get only the top ten movies
topTenMovies= grouped_data.select('movieId','votes','avgRating').take(10)
topTenMovies
# Out:
# [Row(movieId='tt0111161', votes=1957480, avgRating=9.3),
#  Row(movieId='tt0468569', votes=1929695, avgRating=9.0),
#  Row(movieId='tt1375666', votes=1714048, avgRating=8.8),
#  Row(movieId='tt0137523', votes=1569401, avgRating=8.8),
#  Row(movieId='tt0110912', votes=1530948, avgRating=8.9),
#  Row(movieId='tt0109830', votes=1486730, avgRating=8.8),
#  Row(movieId='tt0120737', votes=1414976, avgRating=8.8),
#  Row(movieId='tt0133093', votes=1407146, avgRating=8.7),
#  Row(movieId='tt0167260', votes=1397414, avgRating=8.9),
#  Row(movieId='tt0068646', votes=1340046, avgRating=9.2)]

# %%
votes=[]
for movie in topTenMovies:
    votes.append(movie[1])
votes
# Out:
# [1957480,
#  1929695,
#  1714048,
#  1569401,
#  1530948,
#  1486730,
#  1414976,
#  1407146,
#  1397414,
#  1340046]

# %%
rating=[]
for movie in topTenMovies:
    rating.append(movie[2])
rating
# Out:
# [9.3, 9.0, 8.8, 8.8, 8.9, 8.8, 8.8, 8.7, 8.9, 9.2]

# %%
groupTitle = df_titles.orderBy('movieId')

# %%
#Collect all data for top ten movies
titles=[]
for movies in topTenMovies:
    titles.append(cachedTitles.filter((cachedTitles.movieId == movies[0])).collect())
titles
# Out:
# [[Row(movieId='tt0111161', movieName='The Shawshank Redemption', genre='Crime,Drama')],
#  [Row(movieId='tt0468569', movieName='The Dark Knight', genre='Action,Crime,Drama')],
#  [Row(movieId='tt1375666', movieName='Inception', genre='Action,Adventure,Sci-Fi')],
#  [Row(movieId='tt0137523', movieName='Fight Club', genre='Drama')],
#  [Row(movieId='tt0110912', movieName='Pulp Fiction', genre='Crime,Drama')],
#  [Row(movieId='tt0109830', movieName='Forrest Gump', genre='Drama,Romance')],
#  [Row(movieId='tt0120737', movieName='The Lord of the Rings: The Fellowship of the Ring', genre='Adventure,Drama,Fantasy')],
#  [Row(movieId='tt0133093', movieName='The Matrix', genre='Action,Sci-Fi')],
#  [Row(movieId='tt0167260', movieName='The Lord of the Rings: The Return of the King', genre='Adventure,Drama,Fantasy')],
#  [Row(movieId='tt0068646', movieName='The Godfather', genre='Crime,Drama')]]

# %%
movieNames=[]
genre=[]
for movie in titles:
    movieNames.append(movie[0][1])
    genre.append(movie[0][2])

# %%
print(movieNames)
# Out:
# ['The Shawshank Redemption', 'The Dark Knight', 'Inception', 'Fight Club', 'Pulp Fiction', 'Forrest Gump', 'The Lord of the Rings: The Fellowship of the Ring', 'The Matrix', 'The Lord of the Rings: The Return of the King', 'The Godfather']

# %%
print(genre)
# Out:
# ['Crime,Drama', 'Action,Crime,Drama', 'Action,Adventure,Sci-Fi', 'Drama', 'Crime,Drama', 'Drama,Romance', 'Adventure,Drama,Fantasy', 'Action,Sci-Fi', 'Adventure,Drama,Fantasy', 'Crime,Drama']

# %%
plt.rcdefaults()
fig,ax = plt.subplots(figsize=(12, 6))

# Example data
genres = genre
y_pos = numpy.arange(len(genres))
width = 0.5
ax.barh(y_pos, rating,width, align='center',
        color='purple')
ax.set_yticks(y_pos)
ax.set_yticklabels(genres)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Average Rating')
ax.set_title('Top Ten rated genres')

plt.show()

# %%
plt.rcdefaults()
fig,ax = plt.subplots(figsize=(10, 6))

# Example data
movies = movieNames
y_pos = numpy.arange(len(movies))
width = 0.5
ax.barh(y_pos, votes,width, align='center',
        color='green')
ax.set_yticks(y_pos)
ax.set_yticklabels(movies)
ax.invert_yaxis()  # labels read top-to-bottom
ax.set_xlabel('Votes')
ax.set_title('Top Ten Voted Best Movies of all time')

plt.show()

# %%
#Get Count of Movies by Genre
genreMovieList=[]
genreMovieList.append(cachedTitles.filter(cachedTitles.genre.contains("Action")).collect())

# %%
print("The count of Action Movies are:" + str(len(genreMovieList[0])))
# Out:
# The count of Action Movies are:39832

# %% [markdown]
# ### Make a Prediction based on the running time of the movie into categories like short, tvEpisode and movie
#
# Decision Trees is used for the purposes since the features is continuos and decision tree is very robust to noise

# %%
randomizedTitle = df_titles.orderBy(rand())

# %%
randomizedTitle.printSchema()
# Out:
# root
#  |-- genre: string (nullable = true)
#  |-- movieId: string (nullable = true)
#  |-- movieName: string (nullable = true)
#  |-- movieType: string (nullable = true)
#  |-- runningTime: string (nullable = true)

# %%
#Drop Duplicates if any
#randomizedTitle = randomizedTitle.dropDuplicates()
labels = ["tvEpisode","short","movie"]
titles = randomizedTitle.filter((randomizedTitle.movieType != '\\N' ) & 
                                (randomizedTitle.runningTime != '\\N'))

# %%
selectedTitles = titles.filter(titles.movieType.contains("short") |
                              titles.movieType.contains("movie") |
                              titles.movieType.contains("tvEpisode"))
selectedTitles.take(2)
# Out:
# [Row(genre='Drama', movieId='tt0285904', movieName='I pikragapimeni', movieType='movie', runningTime='78'),
#  Row(genre='Drama', movieId='tt7211226', movieName='Ninety Nine Per Cent', movieType='movie', runningTime='47')]

# %%
dataset = selectedTitles.take(1500)

# %%
filterDataSet = []
#Filter columns
for titles in dataset:
    filterDataSet.append(titles[3:])
    
range = int(len(filterDataSet)*(2/3))
#Make a train and test set
train = filterDataSet[0:range]
test = filterDataSet[len(train):]

# %%
x=[]
y=[]
for data in filterDataSet:
    x.append(data[1])
    y.append(data[0])

# %%
len(train)
# Out:
# 1000

# %%
len(test)
# Out:
# 500

# %%
train[0:]
# Out:
# [('movie', '78'),
#  ('movie', '47'),
#  ('movie', '79'),
#  ('short', '5'),
#  ('movie', '96'),
#  ('short', '13'),
#  ('short', '16'),
#  ('movie', '86'),
#  ('short', '1'),
#  ('tvEpisode', '30'),
#  ('short', '13'),
#  ('tvEpisode', '3'),
#  ('short', '27'),
#  ('tvEpisode', '15'),
#  ('tvEpisode', '52'),
#  ('tvEpisode', '100'),
#  ('tvEpisode', '23'),
#  ('tvEpisode', '22'),
#  ('tvEpisode', '30'),
#  ('short', '10'),
#  ('short', '32'),
#  ('tvEpisode', '115'),
#  ('movie', '91'),
#  ('tvEpisode', '43'),
#  ('tvEpisode', '41'),
#  ('movie', '51'),
#  ('movie', '50'),
#  ('short', '21'),
#  ('movie', '66'),
#  ('short', '13'),
#  ('tvEpisode', '52'),
#  ('tvEpisode', '104'),
#  ('movie', '65'),
#  ('movie', '52'),
#  ('movie', '101'),
#  ('short', '3'),
#  ('short', '12'),
#  ('movie', '81'),
#  ('movie', '53'),
#  ('tvEpisode', '45'),
#  ('movie', '47'),
#  ('short', '30'),
#  ('tvEpisode', '58'),
#  ('short', '8'),
#  ('short', '13'),
#  ('short', '20'),
#  ('tvEpisode', '6'),
#  ('short', '10'),
#  ('movie', '70'),
#  ('tvEpisode', '30'),
#  ('tvEpisode', '43'),
#  ('tvEpisode', '57'),
#  ('tvEpisode', '45'),
#  ('movie', '95'),
#  ('tvEpisode', '22'),
#  ('tvEpisode', '30'),
#  ('tvEpisode', '49'),
#  ('tvEpisode', '7'),
#  ('short', '25'),
#  ('tvEpisode', '43'),
#  ('tvEpisode', '23'),
#  ('short', '10'),
#  ('tvEpisode', '24'),
#  ('short', '15'),
#  ('tvEpisode', '40'),
#  ('tvEpisode', '44'),
#  ('movie', '80'),
#  ('short', '12'),
#  ('tvEpisode', '7'),
#  ('tvEpisode', '60'),
#  ('movie', '83'),
#  ('short', '13'),
#  ('tvEpisode', '43'),
#  ('tvEpisode', '60'),
#  ('tvEpisode', '43'),
#  ('short', '8'),
#  ('short', '5'),
#  ('tvEpisode', '41'),
#  ('short', '15'),
#  ('short', '5'),
#  ('tvEpisode', '46'),
#  ('tvEpisode', '21'),
#  ('short', '6'),
#  ('tvEpisode', '30'),
#  ('short', '7'),
#  ('tvEpisode', '21'),
#  ('movie', '80'),
#  ('tvEpisode', '11'),
#  ('tvEpisode', '43'),
#  ('tvEpisode', '5'),
#  ('tvEpisode', '25'),
#  ('movie', '88'),
#  ('short', '15'),
#  ('short', '15'),
#  ('tvEpisode', '30'),
#  ('tvEpisode', '25'),
#  ('short', '15'),
#  ('short', '9'),
#  ('short', '24'),
#  ('short', '5'),
#  ('tvEpisode', '4'),
#  ('short', '18'),
#  ('tvEpisode', '60'),
#  ('tvEpisode', '41'),
#  ('short', '5'),
#  ('tvEpisode', '22'),
#  ('tvEpisode', '30'),
#  ('short', '1'),
#  ('short', '10'),
#  ('tvEpisode', '43'),
#  ('tvEpisode', '23'),
#  ('tvEpisode', '22'),
#  ('tvEpisode', '34'),
#  ('tvEpisode', '103'),
#  ('movie', '70'),
#  ('tvEpisode', '30'),
#  ('movie', '91'),
#  ('tvEpisode', '5'),
#  ('tvEpisode', '22'),
#  ('short', '11'),
#  ('tvEpisode', '23'),
#  ('movie', '90'),
#  ('short', '10'),
#  ('tvEpisode', '30'),
#  ('short', '14'),
#  ('tvEpisode', '60'),
#  ('tvEpisode', '50'),
#  ('tvEpisode', '21'),
#  ('short', '15'),
#  ('tvEpisode', '90'),
#  ('tvEpisode', '21'),
#  ('movie', '85'),
#  ('movie', '90'),
#  ('short', '13'),
#  ('short', '7'),
#  ('short', '10'),
#  ('short', '2'),
#  ('short', '6'),
#  ('short', '22'),
#  ('movie', '86'),
#  ('short', '6'),
#  ('tvEpisode', '30'),
#  ('movie', '91'),
#  ('short', '2'),
#  ('tvEpisode', '30'),
#  ('short', '10'),
#  ('short', '20'),
#  ('movie', '77'),
#  ('tvEpisode', '30'),
#  ('tvEpisode', '60'),
#  ('tvEpisode', '21'),
#  ('short', '8'),
#  ('short', '6'),
#  ('movie', '145'),
#  ('tvEpisode', '22'),
#  ('tvEpisode', '26'),
#  ('tvEpisode', '44'),
#  ('tvEpisode', '23'),
#  ('tvEpisode', '22'),
#  ('tvEpisode', '43'),
#  ('short', '24'),
#  ('movie', '120'),
#  ('movie', '87'),
#  ('short', '13'),
#  ('movie', '80'),
#  ('short', '20'),
#  ('tvEpisode', '59'),
#  ('tvEpisode', '24'),
#  ('tvEpisode', '81'),
#  ('tvEpisode', '10'),
#  ('movie', '120'),
#  ('tvEpisode', '42'),
#  ('short', '8'),
#  ('tvEpisode', '60'),
#  ('tvEpisode', '115'),
#  ('tvEpisode', '25'),
#  ('movie', '130'),
#  ('tvEpisode', '24'),
#  ('tvEpisode', '60'),
#  ('tvEpisode', '30'),
#  ('tvEpisode', '24'),
#  ('tvEpisode', '10'),
#  ('tvEpisode', '22'),
#  ('tvEpisode', '38'),
#  ('short', '1'),
#  ('short', '14'),
#  ('movie', '55'),
#  ('tvEpisode', '36'),
#  ('tvEpisode', '60'),
#  ('short', '5'),
#  ('tvEpisode', '40'),
#  ('movie', '107'),
#  ('tvEpisode', '44'),
#  ('tvEpisode', '52'),
#  ('tvEpisode', '42'),
#  ('tvEpisode', '23'),
#  ('tvEpisode', '42'),
#  ('tvEpisode', '21'),
#  ('tvEpisode', '43'),
#  ('tvEpisode', '37'),
#  ('tvEpisode', '11'),
#  ('tvEpisode', '43'),
#  ('tvEpisode', '22'),
#  ('tvEpisode', '30'),
#  ('tvEpisode', '46'),
#  ('short', '10'),
#  ('movie', '85'),
#  ('tvEpisode', '41'),
#  ('movie', '92'),
#  ('tvEpisode', '20'),
#  ('short', '2'),
#  ('movie', '85'),
#  ('movie', '103'),
#  ('short', '20'),
#  ('tvEpisode', '30'),
#  ('tvEpisode', '30'),
#  ('tvEpisode', '30'),
#  ('tvEpisode', '22'),
#  ('short', '4'),
#  ('tvEpisode', '44'),
#  ('tvEpisode', '27'),
#  ('tvEpisode', '46'),
#  ('short', '19'),
#  ('tvEpisode', '19'),
#  ('tvEpisode', '43'),
#  ('tvEpisode', '30'),
#  ('movie', '127'),
#  ('movie', '87'),
#  ('movie', '126'),
#  ('tvEpisode', '22'),
#  ('movie', '93'),
#  ('short', '5'),
#  ('tvEpisode', '23'),
#  ('tvEpisode', '23'),
#  ('tvEpisode', '4'),
#  ('tvEpisode', '21'),
#  ('tvEpisode', '29'),
#  ('short', '29'),
#  ('movie', '89'),
#  ('short', '6'),
#  ('short', '40'),
#  ('movie', '115'),
#  ('movie', '52'),
#  ('short', '37'),
#  ('short', '15'),
#  ('tvEpisode', '54'),
#  ('tvEpisode', '30'),
#  ('short', '12'),
#  ('tvEpisode', '51'),
#  ('tvEpisode', '15'),
#  ('movie', '57'),
#  ('short', '15'),
#  ('short', '19'),
#  ('movie', '86'),
#  ('tvEpisode', '23'),
#  ('short', '23'),
#  ('tvEpisode', '30'),
#  ('tvEpisode', '21'),
#  ('movie', '45'),
#  ('tvEpisode', '7'),
#  ('tvEpisode', '60'),
#  ('tvEpisode', '6'),
#  ('movie', '106'),
#  ('short', '18'),
#  ('short', '8'),
#  ('short', '1'),
#  ('movie', '95'),
#  ('short', '18'),
#  ('tvEpisode', '20'),
#  ('short', '14'),
#  ('movie', '86'),
#  ('tvEpisode', '90'),
#  ('movie', '102'),
#  ('movie', '81'),
#  ('movie', '70'),
#  ('short', '10'),
#  ('short', '6'),
#  ('short', '16'),
#  ('tvEpisode', '1'),
#  ('short', '30'),
#  ('short', '17'),
#  ('tvEpisode', '58'),
#  ('tvEpisode', '42'),
#  ('tvEpisode', '22'),
#  ('short', '15'),
#  ('tvEpisode', '45'),
#  ('movie', '17'),
#  ('short', '29'),
#  ('movie', '83'),
#  ('movie', '90'),
#  ('movie', '95'),
#  ('tvEpisode', '44'),
#  ('tvEpisode', '15'),
#  ('short', '15'),
#  ('movie', '94'),
#  ('short', '5'),
#  ('movie', '77'),
#  ('short', '15'),
#  ('short', '2'),
#  ('movie', '60'),
#  ('tvEpisode', '43'),
#  ('short', '5'),
#  ('short', '4'),
#  ('tvEpisode', '24'),
#  ('short', '34'),
#  ('short', '3'),
#  ('movie', '88'),
#  ('movie', '71'),
#  ('tvEpisode', '44'),
#  ('tvEpisode', '42'),
#  ('short', '5'),
#  ('tvEpisode', '115'),
#  ('tvEpisode', '21'),
#  ('movie', '87'),
#  ('movie', '100'),
#  ('short', '10'),
#  ('tvEpisode', '60'),
#  ('movie', '89'),
#  ('tvEpisode', '44'),
#  ('short', '20'),
#  ('short', '13'),
#  ('movie', '63'),
#  ('short', '27'),
#  ('tvEpisode', '50'),
#  ('tvEpisode', '30'),
#  ('short', '12'),
#  ('tvEpisode', '46'),
#  ('movie', '116'),
#  ('short', '29'),
#  ('tvEpisode', '42'),
#  ('short', '5'),
#  ('short', '10'),
#  ('short', '5'),
#  ('short', '12'),
#  ('movie', '124'),
#  ('tvEpisode', '30'),
#  ('movie', '30'),
#  ('tvEpisode', '53'),
#  ('short', '9'),
#  ('short', '3'),
#  ('short', '23'),
#  ('tvEpisode', '22'),
#  ('tvEpisode', '60'),
#  ('short', '20'),
#  ('tvEpisode', '29'),
#  ('tvEpisode', '61'),
#  ('movie', '106'),
#  ('short', '13'),
#  ('short', '12'),
#  ('tvEpisode', '44'),
#  ('short', '7'),
#  ('movie', '90'),
#  ('short', '12'),
#  ('movie', '94'),
#  ('movie', '108'),
#  ('movie', '78'),
#  ('short', '2'),
#  ('movie', '92'),
#  ('short', '15'),
#  ('short', '9'),
#  ('movie', '100'),
#  ('short', '4'),
#  ('tvEpisode', '28'),
#  ('tvEpisode', '28'),
#  ('movie', '67'),
#  ('short', '6'),
#  ('short', '8'),
#  ('movie', '90'),
#  ('tvEpisode', '30'),
#  ('movie', '135'),
#  ('tvEpisode', '29'),
#  ('short', '6'),
#  ('short', '15'),
#  ('short', '39'),
#  ('movie', '90'),
#  ('tvEpisode', '21'),
#  ('movie', '78'),
#  ('tvEpisode', '11'),
#  ('short', '28'),
#  ('short', '11'),
#  ('short', '13'),
#  ('short', '8'),
#  ('movie', '90'),
#  ('tvEpisode', '22'),
#  ('short', '12'),
#  ('tvEpisode', '40'),
#  ('short', '20'),
#  ('tvEpisode', '15'),
#  ('short', '18'),
#  ('tvEpisode', '120'),
#  ('short', '21'),
#  ('tvEpisode', '45'),
#  ('movie', '118'),
#  ('tvEpisode', '25'),
#  ('tvEpisode', '21'),
#  ('tvEpisode', '45'),
#  ('short', '26'),
#  ('tvEpisode', '26'),
#  ('short', '4'),
#  ('tvEpisode', '25'),
#  ('tvEpisode', '23'),
#  ('tvEpisode', '30'),
#  ('short', '10'),
#  ('movie', '57'),
#  ('tvEpisode', '55'),
#  ('tvEpisode', '24'),
#  ('short', '10'),
#  ('tvEpisode', '23'),
#  ('tvEpisode', '42'),
#  ('tvEpisode', '15'),
#  ('short', '3'),
#  ('short', '25'),
#  ('short', '9'),
#  ('movie', '90'),
#  ('tvEpisode', '30'),
#  ('tvEpisode', '30'),
#  ('short', '11'),
#  ('short', '3'),
#  ('tvEpisode', '24'),
#  ('short', '30'),
#  ('short', '9'),
#  ('short', '20'),
#  ('movie', '95'),
#  ('short', '7'),
#  ('tvEpisode', '17'),
#  ('movie', '100'),
#  ('movie', '105'),
#  ('movie', '60'),
#  ('movie', '85'),
#  ('movie', '54'),
#  ('movie', '104'),
#  ('tvEpisode', '28'),
#  ('tvEpisode', '30'),
#  ('tvEpisode', '21'),
#  ('short', '18'),
#  ('tvEpisode', '24'),
#  ('short', '40'),
#  ('tvEpisode', '43'),
#  ('movie', '88'),
#  ('short', '36'),
#  ('tvEpisode', '61'),
#  ('movie', '93'),
#  ('tvEpisode', '9'),
#  ('tvEpisode', '2'),
#  ('tvEpisode', '45'),
#  ('movie', '84'),
#  ('short', '12'),
#  ('tvEpisode', '52'),
#  ('movie', '68'),
#  ('short', '15'),
#  ('short', '18'),
#  ('tvEpisode', '15'),
#  ('tvEpisode', '21'),
#  ('tvEpisode', '24'),
#  ('tvEpisode', '64'),
#  ('tvEpisode', '21'),
#  ('movie', '67'),
#  ('movie', '90'),
#  ('short', '15'),
#  ('movie', '92'),
#  ('tvEpisode', '44'),
#  ('short', '16'),
#  ('tvEpisode', '47'),
#  ('short', '5'),
#  ('tvEpisode', '43'),
#  ('movie', '360'),
#  ('short', '16'),
#  ('tvEpisode', '120'),
#  ('tvEpisode', '82'),
#  ('short', '22'),
#  ('short', '6'),
#  ('short', '7'),
#  ('tvEpisode', '55'),
#  ('short', '30'),
#  ('tvEpisode', '55'),
#  ('tvEpisode', '43'),
#  ('tvEpisode', '60'),
#  ('short', '25'),
#  ('tvEpisode', '21'),
#  ('short', '26'),
#  ('short', '30'),
#  ('movie', '82'),
#  ('movie', '66'),
#  ('tvEpisode', '30'),
#  ('movie', '91'),
#  ('movie', '76'),
#  ('movie', '76'),
#  ('movie', '91'),
#  ('tvEpisode', '10'),
#  ('movie', '50'),
#  ('movie', '82'),
#  ('movie', '100'),
#  ('movie', '105'),
#  ('movie', '77'),
#  ('short', '10'),
#  ('tvEpisode', '44'),
#  ('short', '20'),
#  ('short', '11'),
#  ('tvEpisode', '15'),
#  ('movie', '111'),
#  ('short', '10'),
#  ('movie', '134'),
#  ('tvEpisode', '21'),
#  ('tvEpisode', '22'),
#  ('short', '1'),
#  ('tvEpisode', '22'),
#  ('tvEpisode', '60'),
#  ('tvEpisode', '43'),
#  ('short', '20'),
#  ('tvEpisode', '22'),
#  ('tvEpisode', '42'),
#  ('short', '36'),
#  ('short', '35'),
#  ('tvEpisode', '98'),
#  ('tvEpisode', '60'),
#  ('movie', '87'),
#  ('movie', '99'),
#  ('short', '10'),
#  ('tvEpisode', '30'),
#  ('short', '25'),
#  ('short', '12'),
#  ('tvEpisode', '60'),
#  ('tvEpisode', '45'),
#  ('short', '9'),
#  ('short', '16'),
#  ('tvEpisode', '30'),
#  ('short', '10'),
#  ('tvEpisode', '30'),
#  ('tvEpisode', '43'),
#  ('short', '35'),
#  ('tvEpisode', '28'),
#  ('movie', '51'),
#  ('tvEpisode', '1'),
#  ('tvEpisode', '12'),
#  ('movie', '77'),
#  ('movie', '108'),
#  ('tvEpisode', '42'),
#  ('tvEpisode', '45'),
#  ('movie', '83'),
#  ('short', '3'),
#  ('short', '10'),
#  ('tvEpisode', '30'),
#  ('movie', '95'),
#  ('short', '7'),
#  ('tvEpisode', '24'),
#  ('short', '11'),
#  ('short', '10'),
#  ('movie', '50'),
#  ('movie', '108'),
#  ('tvEpisode', '23'),
#  ('short', '11'),
#  ('tvEpisode', '22'),
#  ('tvEpisode', '60'),
#  ('movie', '72'),
#  ('short', '23'),
#  ('tvEpisode', '26'),
#  ('movie', '84'),
#  ('tvEpisode', '26'),
#  ('tvEpisode', '27'),
#  ('short', '9'),
#  ('tvEpisode', '30'),
#  ('short', '28'),
#  ('movie', '88'),
#  ('movie', '95'),
#  ('movie', '95'),
#  ('movie', '138'),
#  ('movie', '86'),
#  ('movie', '86'),
#  ('short', '10'),
#  ('movie', '84'),
#  ('tvEpisode', '30'),
#  ('tvEpisode', '40'),
#  ('short', '26'),
#  ('short', '20'),
#  ('short', '10'),
#  ('movie', '134'),
#  ('short', '14'),
#  ('tvEpisode', '24'),
#  ('tvEpisode', '30'),
#  ('movie', '95'),
#  ('tvEpisode', '40'),
#  ('movie', '50'),
#  ('tvEpisode', '62'),
#  ('short', '3'),
#  ('tvEpisode', '60'),
#  ('movie', '106'),
#  ('short', '9'),
#  ('tvEpisode', '23'),
#  ('tvEpisode', '42'),
#  ('short', '12'),
#  ('tvEpisode', '95'),
#  ('tvEpisode', '52'),
#  ('tvEpisode', '43'),
#  ('tvEpisode', '43'),
#  ('short', '18'),
#  ('short', '25'),
#  ('tvEpisode', '49'),
#  ('movie', '127'),
#  ('tvEpisode', '44'),
#  ('short', '10'),
#  ('short', '11'),
#  ('short', '2'),
#  ('short', '6'),
#  ('tvEpisode', '44'),
#  ('tvEpisode', '45'),
#  ('tvEpisode', '46'),
#  ('tvEpisode', '60'),
#  ('movie', '95'),
#  ('movie', '71'),
#  ('tvEpisode', '43'),
#  ('tvEpisode', '90'),
#  ('short', '23'),
#  ('tvEpisode', '21'),
#  ('short', '17'),
#  ('tvEpisode', '24'),
#  ('movie', '80'),
#  ('short', '12'),
#  ('tvEpisode', '20'),
#  ('short', '25'),
#  ('short', '18'),
#  ('short', '10'),
#  ('short', '15'),
#  ('short', '14'),
#  ('tvEpisode', '100'),
#  ('tvEpisode', '21'),
#  ('tvEpisode', '60'),
#  ('movie', '95'),
#  ('short', '26'),
#  ('movie', '12'),
#  ('tvEpisode', '6'),
#  ('short', '5'),
#  ('tvEpisode', '25'),
#  ('short', '22'),
#  ('short', '5'),
#  ('tvEpisode', '43'),
#  ('movie', '92'),
#  ('tvEpisode', '23'),
#  ('tvEpisode', '90'),
#  ('short', '14'),
#  ('tvEpisode', '30'),
#  ('movie', '111'),
#  ('short', '11'),
#  ('tvEpisode', '10'),
#  ('tvEpisode', '24'),
#  ('tvEpisode', '60'),
#  ('short', '5'),
#  ('movie', '87'),
#  ('tvEpisode', '30'),
#  ('short', '3'),
#  ('movie', '110'),
#  ('tvEpisode', '28'),
#  ('movie', '112'),
#  ('tvEpisode', '82'),
#  ('short', '17'),
#  ('movie', '59'),
#  ('movie', '94'),
#  ('tvEpisode', '60'),
#  ('tvEpisode', '23'),
#  ('short', '20'),
#  ('tvEpisode', '11'),
#  ('short', '10'),
#  ('short', '5'),
#  ('short', '11'),
#  ('tvEpisode', '21'),
#  ('short', '10'),
#  ('short', '10'),
#  ('tvEpisode', '47'),
#  ('tvEpisode', '10'),
#  ('short', '6'),
#  ('movie', '85'),
#  ('short', '23'),
#  ('tvEpisode', '30'),
#  ('movie', '82'),
#  ('tvEpisode', '30'),
#  ('tvEpisode', '43'),
#  ('short', '5'),
#  ('tvEpisode', '60'),
#  ('tvEpisode', '42'),
#  ('tvEpisode', '110'),
#  ('short', '7'),
#  ('tvEpisode', '26'),
#  ('tvEpisode', '23'),
#  ('tvEpisode', '32'),
#  ('tvEpisode', '27'),
#  ('short', '4'),
#  ('movie', '64'),
#  ('short', '35'),
#  ('movie', '92'),
#  ('short', '17'),
#  ('tvEpisode', '21'),
#  ('short', '3'),
#  ('movie', '60'),
#  ('short', '8'),
#  ('short', '15'),
#  ('tvEpisode', '24'),
#  ('movie', '111'),
#  ('short', '7'),
#  ('short', '28'),
#  ('movie', '95'),
#  ('tvEpisode', '60'),
#  ('short', '7'),
#  ('short', '24'),
#  ('movie', '92'),
#  ('movie', '102'),
#  ('tvEpisode', '5'),
#  ('movie', '94'),
#  ('tvEpisode', '14'),
#  ('tvEpisode', '46'),
#  ('movie', '85'),
#  ('movie', '50'),
#  ('short', '2'),
#  ('tvEpisode', '60'),
#  ('tvEpisode', '25'),
#  ('movie', '59'),
#  ('short', '2'),
#  ('movie', '70'),
#  ('tvEpisode', '40'),
#  ('short', '2'),
#  ('movie', '85'),
#  ('movie', '89'),
#  ('tvEpisode', '24'),
#  ('short', '11'),
#  ('tvEpisode', '41'),
#  ('short', '35'),
#  ('short', '8'),
#  ('tvEpisode', '30'),
#  ('tvEpisode', '45'),
#  ('movie', '88'),
#  ('tvEpisode', '53'),
#  ('tvEpisode', '10'),
#  ('short', '11'),
#  ('movie', '96'),
#  ('tvEpisode', '22'),
#  ('movie', '97'),
#  ('tvEpisode', '22'),
#  ('movie', '100'),
#  ('tvEpisode', '52'),
#  ('movie', '160'),
#  ('movie', '110'),
#  ('tvEpisode', '47'),
#  ('tvEpisode', '15'),
#  ('short', '5'),
#  ('tvEpisode', '30'),
#  ('short', '35'),
#  ('tvEpisode', '41'),
#  ('tvEpisode', '30'),
#  ('tvEpisode', '12'),
#  ('tvEpisode', '10'),
#  ('short', '3'),
#  ('movie', '103'),
#  ('tvEpisode', '3'),
#  ('tvEpisode', '47'),
#  ('tvEpisode', '67'),
#  ('tvEpisode', '45'),
#  ('short', '27'),
#  ('short', '7'),
#  ('movie', '88'),
#  ('short', '3'),
#  ('tvEpisode', '16'),
#  ('short', '15'),
#  ('tvEpisode', '60'),
#  ('short', '30'),
#  ('tvEpisode', '12'),
#  ('short', '10'),
#  ('short', '16'),
#  ('short', '23'),
#  ('short', '27'),
#  ('movie', '165'),
#  ('short', '4'),
#  ('movie', '52'),
#  ('tvEpisode', '24'),
#  ('movie', '35'),
#  ('tvEpisode', '15'),
#  ('tvEpisode', '28'),
#  ('short', '34'),
#  ('short', '14'),
#  ('tvEpisode', '22'),
#  ('tvEpisode', '23'),
#  ('movie', '90'),
#  ('short', '5'),
#  ('tvEpisode', '30'),
#  ('movie', '90'),
#  ('movie', '84'),
#  ('short', '8'),
#  ('movie', '89'),
#  ('tvEpisode', '23'),
#  ('short', '7'),
#  ('short', '3'),
#  ('movie', '89'),
#  ('short', '16'),
#  ('tvEpisode', '30'),
#  ('short', '2'),
#  ('tvEpisode', '3'),
#  ('movie', '84'),
#  ('tvEpisode', '21'),
#  ('tvEpisode', '30'),
#  ('movie', '48'),
#  ('tvEpisode', '5'),
#  ('tvEpisode', '42'),
#  ('tvEpisode', '50'),
#  ('tvEpisode', '26'),
#  ('short', '42'),
#  ('short', '2'),
#  ('tvEpisode', '44'),
#  ('tvEpisode', '22'),
#  ('short', '25'),
#  ('short', '18'),
#  ('movie', '95'),
#  ('short', '6'),
#  ('tvEpisode', '12'),
#  ('tvEpisode', '24'),
#  ('tvEpisode', '45'),
#  ('tvEpisode', '30'),
#  ('short', '15'),
#  ('tvEpisode', '24'),
#  ('short', '14'),
#  ('movie', '54'),
#  ('tvEpisode', '30'),
#  ('tvEpisode', '25'),
#  ('tvEpisode', '29'),
#  ('short', '2'),
#  ('tvEpisode', '59'),
#  ('short', '13'),
#  ('short', '19'),
#  ('short', '17'),
#  ('movie', '96'),
#  ('tvEpisode', '21'),
#  ('short', '12'),
#  ('tvEpisode', '21'),
#  ('tvEpisode', '44'),
#  ('short', '14'),
#  ('tvEpisode', '42'),
#  ('movie', '110'),
#  ('short', '10'),
#  ('tvEpisode', '42'),
#  ('tvEpisode', '30'),
#  ('short', '15'),
#  ('short', '18'),
#  ('short', '9'),
#  ('short', '9'),
#  ('movie', '110'),
#  ('tvEpisode', '43'),
#  ('movie', '120'),
#  ('movie', '74'),
#  ('short', '15'),
#  ('short', '10'),
#  ('tvEpisode', '22'),
#  ('movie', '89'),
#  ('short', '14'),
#  ('movie', '13'),
#  ('movie', '85'),
#  ('tvEpisode', '44'),
#  ('tvEpisode', '21'),
#  ('movie', '78'),
#  ('tvEpisode', '26'),
#  ('tvEpisode', '45'),
#  ('tvEpisode', '8'),
#  ('short', '15'),
#  ('short', '12'),
#  ('tvEpisode', '22'),
#  ('tvEpisode', '47'),
#  ('tvEpisode', '28'),
#  ('movie', '112'),
#  ('tvEpisode', '120'),
#  ('movie', '72'),
#  ('short', '18'),
#  ('tvEpisode', '27'),
#  ('tvEpisode', '37'),
#  ('movie', '46'),
#  ('tvEpisode', '43'),
#  ('movie', '110'),
#  ('tvEpisode', '23'),
#  ('tvEpisode', '22'),
#  ('short', '21'),
#  ('short', '9'),
#  ('movie', '47'),
#  ('movie', '82'),
#  ('tvEpisode', '3'),
#  ('tvEpisode', '47'),
#  ('tvEpisode', '50'),
#  ('movie', '80'),
#  ('movie', '100'),
#  ('tvEpisode', '30'),
#  ('movie', '55'),
#  ('movie', '65'),
#  ('short', '4'),
#  ('tvEpisode', '49'),
#  ('short', '24'),
#  ('short', '4'),
#  ('movie', '88'),
#  ('short', '10'),
#  ('tvEpisode', '42'),
#  ('tvEpisode', '28'),
#  ('tvEpisode', '30'),
#  ('tvEpisode', '22'),
#  ('movie', '83'),
#  ('short', '4'),
#  ('tvEpisode', '25'),
#  ('movie', '45'),
#  ('tvEpisode', '26'),
#  ('short', '8'),
#  ('tvEpisode', '114'),
#  ('short', '10'),
#  ('tvEpisode', '22'),
#  ('short', '15'),
#  ('tvEpisode', '28'),
#  ('short', '10'),
#  ('movie', '89'),
#  ('tvEpisode', '21'),
#  ('short', '11'),
#  ('movie', '55'),
#  ('tvEpisode', '5'),
#  ('tvEpisode', '18'),
#  ('movie', '55'),
#  ('short', '12'),
#  ('short', '15'),
#  ('short', '25'),
#  ('movie', '52'),
#  ('short', '17'),
#  ('short', '7'),
#  ('tvEpisode', '60'),
#  ('tvEpisode', '22'),
#  ('short', '8'),
#  ('movie', '74'),
#  ('tvEpisode', '53'),
#  ('movie', '52'),
#  ('movie', '51'),
#  ('tvEpisode', '53'),
#  ('tvEpisode', '21'),
#  ('short', '7'),
#  ('short', '7'),
#  ('tvEpisode', '30'),
#  ('short', '10'),
#  ('movie', '57'),
#  ('short', '14'),
#  ('short', '9'),
#  ('short', '7'),
#  ('movie', '67'),
#  ('tvEpisode', '29'),
#  ('tvEpisode', '45'),
#  ('tvEpisode', '23'),
#  ('movie', '72'),
#  ('tvEpisode', '60'),
#  ('tvEpisode', '30'),
#  ('short', '7'),
#  ('tvEpisode', '54'),
#  ('movie', '94'),
#  ('movie', '97'),
#  ('short', '20'),
#  ('short', '7'),
#  ('tvEpisode', '23'),
#  ('tvEpisode', '55'),
#  ('short', '4'),
#  ('movie', '126'),
#  ('movie', '96'),
#  ('movie', '93'),
#  ('tvEpisode', '98'),
#  ('tvEpisode', '9'),
#  ('movie', '92'),
#  ('movie', '94'),
#  ('tvEpisode', '60'),
#  ('short', '14'),
#  ('movie', '50'),
#  ('short', '3'),
#  ('short', '4'),
#  ('tvEpisode', '16'),
#  ('movie', '79'),
#  ('tvEpisode', '49'),
#  ('tvEpisode', '60'),
#  ('tvEpisode', '22'),
#  ('tvEpisode', '22'),
#  ('tvEpisode', '10'),
#  ('movie', '80'),
#  ('short', '7'),
#  ('movie', '92'),
#  ('tvEpisode', '21'),
#  ('tvEpisode', '85'),
#  ('tvEpisode', '21'),
#  ('tvEpisode', '45'),
#  ('movie', '97'),
#  ('movie', '80'),
#  ('tvEpisode', '60'),
#  ('movie', '100'),
#  ('movie', '58'),
#  ('short', '5'),
#  ('tvEpisode', '17'),
#  ('movie', '92'),
#  ('movie', '150'),
#  ('short', '5'),
#  ('movie', '45'),
#  ('tvEpisode', '22'),
#  ('tvEpisode', '29'),
#  ('tvEpisode', '14'),
#  ('short', '7'),
#  ('short', '10'),
#  ('tvEpisode', '60'),
#  ('short', '22'),
#  ('tvEpisode', '30'),
#  ('short', '20'),
#  ('tvEpisode', '25')]

# %%
def getLabelVal(line,flag):
    ordinalValues = {
    0:"short",
    2:"tvEpisode",
    1:"movie"
}
    for key,val in ordinalValues.items():
        if(flag):
            if key == line:
                return val
        if val == line:
            return key

# %%
unique=[]
for line in train:
    if line[0] not in unique:
        unique.append(line[0])
unique
# Out:
# ['movie', 'short', 'tvEpisode']

# %%
def makeTrainData(line,flag=False):
    label = float(getLabelVal(line[0],flag))
    features = Vectors.dense(float(line[1]))
    return LabeledPoint(label, features)

# %%
labelTrainSet = []
for line in train:
    labelTrainSet.append(makeTrainData(line))
labelTrainSet
# Out:
# [LabeledPoint(1.0, [78.0]),
#  LabeledPoint(1.0, [47.0]),
#  LabeledPoint(1.0, [79.0]),
#  LabeledPoint(0.0, [5.0]),
#  LabeledPoint(1.0, [96.0]),
#  LabeledPoint(0.0, [13.0]),
#  LabeledPoint(0.0, [16.0]),
#  LabeledPoint(1.0, [86.0]),
#  LabeledPoint(0.0, [1.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(0.0, [13.0]),
#  LabeledPoint(2.0, [3.0]),
#  LabeledPoint(0.0, [27.0]),
#  LabeledPoint(2.0, [15.0]),
#  LabeledPoint(2.0, [52.0]),
#  LabeledPoint(2.0, [100.0]),
#  LabeledPoint(2.0, [23.0]),
#  LabeledPoint(2.0, [22.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(0.0, [10.0]),
#  LabeledPoint(0.0, [32.0]),
#  LabeledPoint(2.0, [115.0]),
#  LabeledPoint(1.0, [91.0]),
#  LabeledPoint(2.0, [43.0]),
#  LabeledPoint(2.0, [41.0]),
#  LabeledPoint(1.0, [51.0]),
#  LabeledPoint(1.0, [50.0]),
#  LabeledPoint(0.0, [21.0]),
#  LabeledPoint(1.0, [66.0]),
#  LabeledPoint(0.0, [13.0]),
#  LabeledPoint(2.0, [52.0]),
#  LabeledPoint(2.0, [104.0]),
#  LabeledPoint(1.0, [65.0]),
#  LabeledPoint(1.0, [52.0]),
#  LabeledPoint(1.0, [101.0]),
#  LabeledPoint(0.0, [3.0]),
#  LabeledPoint(0.0, [12.0]),
#  LabeledPoint(1.0, [81.0]),
#  LabeledPoint(1.0, [53.0]),
#  LabeledPoint(2.0, [45.0]),
#  LabeledPoint(1.0, [47.0]),
#  LabeledPoint(0.0, [30.0]),
#  LabeledPoint(2.0, [58.0]),
#  LabeledPoint(0.0, [8.0]),
#  LabeledPoint(0.0, [13.0]),
#  LabeledPoint(0.0, [20.0]),
#  LabeledPoint(2.0, [6.0]),
#  LabeledPoint(0.0, [10.0]),
#  LabeledPoint(1.0, [70.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(2.0, [43.0]),
#  LabeledPoint(2.0, [57.0]),
#  LabeledPoint(2.0, [45.0]),
#  LabeledPoint(1.0, [95.0]),
#  LabeledPoint(2.0, [22.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(2.0, [49.0]),
#  LabeledPoint(2.0, [7.0]),
#  LabeledPoint(0.0, [25.0]),
#  LabeledPoint(2.0, [43.0]),
#  LabeledPoint(2.0, [23.0]),
#  LabeledPoint(0.0, [10.0]),
#  LabeledPoint(2.0, [24.0]),
#  LabeledPoint(0.0, [15.0]),
#  LabeledPoint(2.0, [40.0]),
#  LabeledPoint(2.0, [44.0]),
#  LabeledPoint(1.0, [80.0]),
#  LabeledPoint(0.0, [12.0]),
#  LabeledPoint(2.0, [7.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(1.0, [83.0]),
#  LabeledPoint(0.0, [13.0]),
#  LabeledPoint(2.0, [43.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(2.0, [43.0]),
#  LabeledPoint(0.0, [8.0]),
#  LabeledPoint(0.0, [5.0]),
#  LabeledPoint(2.0, [41.0]),
#  LabeledPoint(0.0, [15.0]),
#  LabeledPoint(0.0, [5.0]),
#  LabeledPoint(2.0, [46.0]),
#  LabeledPoint(2.0, [21.0]),
#  LabeledPoint(0.0, [6.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(0.0, [7.0]),
#  LabeledPoint(2.0, [21.0]),
#  LabeledPoint(1.0, [80.0]),
#  LabeledPoint(2.0, [11.0]),
#  LabeledPoint(2.0, [43.0]),
#  LabeledPoint(2.0, [5.0]),
#  LabeledPoint(2.0, [25.0]),
#  LabeledPoint(1.0, [88.0]),
#  LabeledPoint(0.0, [15.0]),
#  LabeledPoint(0.0, [15.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(2.0, [25.0]),
#  LabeledPoint(0.0, [15.0]),
#  LabeledPoint(0.0, [9.0]),
#  LabeledPoint(0.0, [24.0]),
#  LabeledPoint(0.0, [5.0]),
#  LabeledPoint(2.0, [4.0]),
#  LabeledPoint(0.0, [18.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(2.0, [41.0]),
#  LabeledPoint(0.0, [5.0]),
#  LabeledPoint(2.0, [22.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(0.0, [1.0]),
#  LabeledPoint(0.0, [10.0]),
#  LabeledPoint(2.0, [43.0]),
#  LabeledPoint(2.0, [23.0]),
#  LabeledPoint(2.0, [22.0]),
#  LabeledPoint(2.0, [34.0]),
#  LabeledPoint(2.0, [103.0]),
#  LabeledPoint(1.0, [70.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(1.0, [91.0]),
#  LabeledPoint(2.0, [5.0]),
#  LabeledPoint(2.0, [22.0]),
#  LabeledPoint(0.0, [11.0]),
#  LabeledPoint(2.0, [23.0]),
#  LabeledPoint(1.0, [90.0]),
#  LabeledPoint(0.0, [10.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(0.0, [14.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(2.0, [50.0]),
#  LabeledPoint(2.0, [21.0]),
#  LabeledPoint(0.0, [15.0]),
#  LabeledPoint(2.0, [90.0]),
#  LabeledPoint(2.0, [21.0]),
#  LabeledPoint(1.0, [85.0]),
#  LabeledPoint(1.0, [90.0]),
#  LabeledPoint(0.0, [13.0]),
#  LabeledPoint(0.0, [7.0]),
#  LabeledPoint(0.0, [10.0]),
#  LabeledPoint(0.0, [2.0]),
#  LabeledPoint(0.0, [6.0]),
#  LabeledPoint(0.0, [22.0]),
#  LabeledPoint(1.0, [86.0]),
#  LabeledPoint(0.0, [6.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(1.0, [91.0]),
#  LabeledPoint(0.0, [2.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(0.0, [10.0]),
#  LabeledPoint(0.0, [20.0]),
#  LabeledPoint(1.0, [77.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(2.0, [21.0]),
#  LabeledPoint(0.0, [8.0]),
#  LabeledPoint(0.0, [6.0]),
#  LabeledPoint(1.0, [145.0]),
#  LabeledPoint(2.0, [22.0]),
#  LabeledPoint(2.0, [26.0]),
#  LabeledPoint(2.0, [44.0]),
#  LabeledPoint(2.0, [23.0]),
#  LabeledPoint(2.0, [22.0]),
#  LabeledPoint(2.0, [43.0]),
#  LabeledPoint(0.0, [24.0]),
#  LabeledPoint(1.0, [120.0]),
#  LabeledPoint(1.0, [87.0]),
#  LabeledPoint(0.0, [13.0]),
#  LabeledPoint(1.0, [80.0]),
#  LabeledPoint(0.0, [20.0]),
#  LabeledPoint(2.0, [59.0]),
#  LabeledPoint(2.0, [24.0]),
#  LabeledPoint(2.0, [81.0]),
#  LabeledPoint(2.0, [10.0]),
#  LabeledPoint(1.0, [120.0]),
#  LabeledPoint(2.0, [42.0]),
#  LabeledPoint(0.0, [8.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(2.0, [115.0]),
#  LabeledPoint(2.0, [25.0]),
#  LabeledPoint(1.0, [130.0]),
#  LabeledPoint(2.0, [24.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(2.0, [24.0]),
#  LabeledPoint(2.0, [10.0]),
#  LabeledPoint(2.0, [22.0]),
#  LabeledPoint(2.0, [38.0]),
#  LabeledPoint(0.0, [1.0]),
#  LabeledPoint(0.0, [14.0]),
#  LabeledPoint(1.0, [55.0]),
#  LabeledPoint(2.0, [36.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(0.0, [5.0]),
#  LabeledPoint(2.0, [40.0]),
#  LabeledPoint(1.0, [107.0]),
#  LabeledPoint(2.0, [44.0]),
#  LabeledPoint(2.0, [52.0]),
#  LabeledPoint(2.0, [42.0]),
#  LabeledPoint(2.0, [23.0]),
#  LabeledPoint(2.0, [42.0]),
#  LabeledPoint(2.0, [21.0]),
#  LabeledPoint(2.0, [43.0]),
#  LabeledPoint(2.0, [37.0]),
#  LabeledPoint(2.0, [11.0]),
#  LabeledPoint(2.0, [43.0]),
#  LabeledPoint(2.0, [22.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(2.0, [46.0]),
#  LabeledPoint(0.0, [10.0]),
#  LabeledPoint(1.0, [85.0]),
#  LabeledPoint(2.0, [41.0]),
#  LabeledPoint(1.0, [92.0]),
#  LabeledPoint(2.0, [20.0]),
#  LabeledPoint(0.0, [2.0]),
#  LabeledPoint(1.0, [85.0]),
#  LabeledPoint(1.0, [103.0]),
#  LabeledPoint(0.0, [20.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(2.0, [22.0]),
#  LabeledPoint(0.0, [4.0]),
#  LabeledPoint(2.0, [44.0]),
#  LabeledPoint(2.0, [27.0]),
#  LabeledPoint(2.0, [46.0]),
#  LabeledPoint(0.0, [19.0]),
#  LabeledPoint(2.0, [19.0]),
#  LabeledPoint(2.0, [43.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(1.0, [127.0]),
#  LabeledPoint(1.0, [87.0]),
#  LabeledPoint(1.0, [126.0]),
#  LabeledPoint(2.0, [22.0]),
#  LabeledPoint(1.0, [93.0]),
#  LabeledPoint(0.0, [5.0]),
#  LabeledPoint(2.0, [23.0]),
#  LabeledPoint(2.0, [23.0]),
#  LabeledPoint(2.0, [4.0]),
#  LabeledPoint(2.0, [21.0]),
#  LabeledPoint(2.0, [29.0]),
#  LabeledPoint(0.0, [29.0]),
#  LabeledPoint(1.0, [89.0]),
#  LabeledPoint(0.0, [6.0]),
#  LabeledPoint(0.0, [40.0]),
#  LabeledPoint(1.0, [115.0]),
#  LabeledPoint(1.0, [52.0]),
#  LabeledPoint(0.0, [37.0]),
#  LabeledPoint(0.0, [15.0]),
#  LabeledPoint(2.0, [54.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(0.0, [12.0]),
#  LabeledPoint(2.0, [51.0]),
#  LabeledPoint(2.0, [15.0]),
#  LabeledPoint(1.0, [57.0]),
#  LabeledPoint(0.0, [15.0]),
#  LabeledPoint(0.0, [19.0]),
#  LabeledPoint(1.0, [86.0]),
#  LabeledPoint(2.0, [23.0]),
#  LabeledPoint(0.0, [23.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(2.0, [21.0]),
#  LabeledPoint(1.0, [45.0]),
#  LabeledPoint(2.0, [7.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(2.0, [6.0]),
#  LabeledPoint(1.0, [106.0]),
#  LabeledPoint(0.0, [18.0]),
#  LabeledPoint(0.0, [8.0]),
#  LabeledPoint(0.0, [1.0]),
#  LabeledPoint(1.0, [95.0]),
#  LabeledPoint(0.0, [18.0]),
#  LabeledPoint(2.0, [20.0]),
#  LabeledPoint(0.0, [14.0]),
#  LabeledPoint(1.0, [86.0]),
#  LabeledPoint(2.0, [90.0]),
#  LabeledPoint(1.0, [102.0]),
#  LabeledPoint(1.0, [81.0]),
#  LabeledPoint(1.0, [70.0]),
#  LabeledPoint(0.0, [10.0]),
#  LabeledPoint(0.0, [6.0]),
#  LabeledPoint(0.0, [16.0]),
#  LabeledPoint(2.0, [1.0]),
#  LabeledPoint(0.0, [30.0]),
#  LabeledPoint(0.0, [17.0]),
#  LabeledPoint(2.0, [58.0]),
#  LabeledPoint(2.0, [42.0]),
#  LabeledPoint(2.0, [22.0]),
#  LabeledPoint(0.0, [15.0]),
#  LabeledPoint(2.0, [45.0]),
#  LabeledPoint(1.0, [17.0]),
#  LabeledPoint(0.0, [29.0]),
#  LabeledPoint(1.0, [83.0]),
#  LabeledPoint(1.0, [90.0]),
#  LabeledPoint(1.0, [95.0]),
#  LabeledPoint(2.0, [44.0]),
#  LabeledPoint(2.0, [15.0]),
#  LabeledPoint(0.0, [15.0]),
#  LabeledPoint(1.0, [94.0]),
#  LabeledPoint(0.0, [5.0]),
#  LabeledPoint(1.0, [77.0]),
#  LabeledPoint(0.0, [15.0]),
#  LabeledPoint(0.0, [2.0]),
#  LabeledPoint(1.0, [60.0]),
#  LabeledPoint(2.0, [43.0]),
#  LabeledPoint(0.0, [5.0]),
#  LabeledPoint(0.0, [4.0]),
#  LabeledPoint(2.0, [24.0]),
#  LabeledPoint(0.0, [34.0]),
#  LabeledPoint(0.0, [3.0]),
#  LabeledPoint(1.0, [88.0]),
#  LabeledPoint(1.0, [71.0]),
#  LabeledPoint(2.0, [44.0]),
#  LabeledPoint(2.0, [42.0]),
#  LabeledPoint(0.0, [5.0]),
#  LabeledPoint(2.0, [115.0]),
#  LabeledPoint(2.0, [21.0]),
#  LabeledPoint(1.0, [87.0]),
#  LabeledPoint(1.0, [100.0]),
#  LabeledPoint(0.0, [10.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(1.0, [89.0]),
#  LabeledPoint(2.0, [44.0]),
#  LabeledPoint(0.0, [20.0]),
#  LabeledPoint(0.0, [13.0]),
#  LabeledPoint(1.0, [63.0]),
#  LabeledPoint(0.0, [27.0]),
#  LabeledPoint(2.0, [50.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(0.0, [12.0]),
#  LabeledPoint(2.0, [46.0]),
#  LabeledPoint(1.0, [116.0]),
#  LabeledPoint(0.0, [29.0]),
#  LabeledPoint(2.0, [42.0]),
#  LabeledPoint(0.0, [5.0]),
#  LabeledPoint(0.0, [10.0]),
#  LabeledPoint(0.0, [5.0]),
#  LabeledPoint(0.0, [12.0]),
#  LabeledPoint(1.0, [124.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(1.0, [30.0]),
#  LabeledPoint(2.0, [53.0]),
#  LabeledPoint(0.0, [9.0]),
#  LabeledPoint(0.0, [3.0]),
#  LabeledPoint(0.0, [23.0]),
#  LabeledPoint(2.0, [22.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(0.0, [20.0]),
#  LabeledPoint(2.0, [29.0]),
#  LabeledPoint(2.0, [61.0]),
#  LabeledPoint(1.0, [106.0]),
#  LabeledPoint(0.0, [13.0]),
#  LabeledPoint(0.0, [12.0]),
#  LabeledPoint(2.0, [44.0]),
#  LabeledPoint(0.0, [7.0]),
#  LabeledPoint(1.0, [90.0]),
#  LabeledPoint(0.0, [12.0]),
#  LabeledPoint(1.0, [94.0]),
#  LabeledPoint(1.0, [108.0]),
#  LabeledPoint(1.0, [78.0]),
#  LabeledPoint(0.0, [2.0]),
#  LabeledPoint(1.0, [92.0]),
#  LabeledPoint(0.0, [15.0]),
#  LabeledPoint(0.0, [9.0]),
#  LabeledPoint(1.0, [100.0]),
#  LabeledPoint(0.0, [4.0]),
#  LabeledPoint(2.0, [28.0]),
#  LabeledPoint(2.0, [28.0]),
#  LabeledPoint(1.0, [67.0]),
#  LabeledPoint(0.0, [6.0]),
#  LabeledPoint(0.0, [8.0]),
#  LabeledPoint(1.0, [90.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(1.0, [135.0]),
#  LabeledPoint(2.0, [29.0]),
#  LabeledPoint(0.0, [6.0]),
#  LabeledPoint(0.0, [15.0]),
#  LabeledPoint(0.0, [39.0]),
#  LabeledPoint(1.0, [90.0]),
#  LabeledPoint(2.0, [21.0]),
#  LabeledPoint(1.0, [78.0]),
#  LabeledPoint(2.0, [11.0]),
#  LabeledPoint(0.0, [28.0]),
#  LabeledPoint(0.0, [11.0]),
#  LabeledPoint(0.0, [13.0]),
#  LabeledPoint(0.0, [8.0]),
#  LabeledPoint(1.0, [90.0]),
#  LabeledPoint(2.0, [22.0]),
#  LabeledPoint(0.0, [12.0]),
#  LabeledPoint(2.0, [40.0]),
#  LabeledPoint(0.0, [20.0]),
#  LabeledPoint(2.0, [15.0]),
#  LabeledPoint(0.0, [18.0]),
#  LabeledPoint(2.0, [120.0]),
#  LabeledPoint(0.0, [21.0]),
#  LabeledPoint(2.0, [45.0]),
#  LabeledPoint(1.0, [118.0]),
#  LabeledPoint(2.0, [25.0]),
#  LabeledPoint(2.0, [21.0]),
#  LabeledPoint(2.0, [45.0]),
#  LabeledPoint(0.0, [26.0]),
#  LabeledPoint(2.0, [26.0]),
#  LabeledPoint(0.0, [4.0]),
#  LabeledPoint(2.0, [25.0]),
#  LabeledPoint(2.0, [23.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(0.0, [10.0]),
#  LabeledPoint(1.0, [57.0]),
#  LabeledPoint(2.0, [55.0]),
#  LabeledPoint(2.0, [24.0]),
#  LabeledPoint(0.0, [10.0]),
#  LabeledPoint(2.0, [23.0]),
#  LabeledPoint(2.0, [42.0]),
#  LabeledPoint(2.0, [15.0]),
#  LabeledPoint(0.0, [3.0]),
#  LabeledPoint(0.0, [25.0]),
#  LabeledPoint(0.0, [9.0]),
#  LabeledPoint(1.0, [90.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(0.0, [11.0]),
#  LabeledPoint(0.0, [3.0]),
#  LabeledPoint(2.0, [24.0]),
#  LabeledPoint(0.0, [30.0]),
#  LabeledPoint(0.0, [9.0]),
#  LabeledPoint(0.0, [20.0]),
#  LabeledPoint(1.0, [95.0]),
#  LabeledPoint(0.0, [7.0]),
#  LabeledPoint(2.0, [17.0]),
#  LabeledPoint(1.0, [100.0]),
#  LabeledPoint(1.0, [105.0]),
#  LabeledPoint(1.0, [60.0]),
#  LabeledPoint(1.0, [85.0]),
#  LabeledPoint(1.0, [54.0]),
#  LabeledPoint(1.0, [104.0]),
#  LabeledPoint(2.0, [28.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(2.0, [21.0]),
#  LabeledPoint(0.0, [18.0]),
#  LabeledPoint(2.0, [24.0]),
#  LabeledPoint(0.0, [40.0]),
#  LabeledPoint(2.0, [43.0]),
#  LabeledPoint(1.0, [88.0]),
#  LabeledPoint(0.0, [36.0]),
#  LabeledPoint(2.0, [61.0]),
#  LabeledPoint(1.0, [93.0]),
#  LabeledPoint(2.0, [9.0]),
#  LabeledPoint(2.0, [2.0]),
#  LabeledPoint(2.0, [45.0]),
#  LabeledPoint(1.0, [84.0]),
#  LabeledPoint(0.0, [12.0]),
#  LabeledPoint(2.0, [52.0]),
#  LabeledPoint(1.0, [68.0]),
#  LabeledPoint(0.0, [15.0]),
#  LabeledPoint(0.0, [18.0]),
#  LabeledPoint(2.0, [15.0]),
#  LabeledPoint(2.0, [21.0]),
#  LabeledPoint(2.0, [24.0]),
#  LabeledPoint(2.0, [64.0]),
#  LabeledPoint(2.0, [21.0]),
#  LabeledPoint(1.0, [67.0]),
#  LabeledPoint(1.0, [90.0]),
#  LabeledPoint(0.0, [15.0]),
#  LabeledPoint(1.0, [92.0]),
#  LabeledPoint(2.0, [44.0]),
#  LabeledPoint(0.0, [16.0]),
#  LabeledPoint(2.0, [47.0]),
#  LabeledPoint(0.0, [5.0]),
#  LabeledPoint(2.0, [43.0]),
#  LabeledPoint(1.0, [360.0]),
#  LabeledPoint(0.0, [16.0]),
#  LabeledPoint(2.0, [120.0]),
#  LabeledPoint(2.0, [82.0]),
#  LabeledPoint(0.0, [22.0]),
#  LabeledPoint(0.0, [6.0]),
#  LabeledPoint(0.0, [7.0]),
#  LabeledPoint(2.0, [55.0]),
#  LabeledPoint(0.0, [30.0]),
#  LabeledPoint(2.0, [55.0]),
#  LabeledPoint(2.0, [43.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(0.0, [25.0]),
#  LabeledPoint(2.0, [21.0]),
#  LabeledPoint(0.0, [26.0]),
#  LabeledPoint(0.0, [30.0]),
#  LabeledPoint(1.0, [82.0]),
#  LabeledPoint(1.0, [66.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(1.0, [91.0]),
#  LabeledPoint(1.0, [76.0]),
#  LabeledPoint(1.0, [76.0]),
#  LabeledPoint(1.0, [91.0]),
#  LabeledPoint(2.0, [10.0]),
#  LabeledPoint(1.0, [50.0]),
#  LabeledPoint(1.0, [82.0]),
#  LabeledPoint(1.0, [100.0]),
#  LabeledPoint(1.0, [105.0]),
#  LabeledPoint(1.0, [77.0]),
#  LabeledPoint(0.0, [10.0]),
#  LabeledPoint(2.0, [44.0]),
#  LabeledPoint(0.0, [20.0]),
#  LabeledPoint(0.0, [11.0]),
#  LabeledPoint(2.0, [15.0]),
#  LabeledPoint(1.0, [111.0]),
#  LabeledPoint(0.0, [10.0]),
#  LabeledPoint(1.0, [134.0]),
#  LabeledPoint(2.0, [21.0]),
#  LabeledPoint(2.0, [22.0]),
#  LabeledPoint(0.0, [1.0]),
#  LabeledPoint(2.0, [22.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(2.0, [43.0]),
#  LabeledPoint(0.0, [20.0]),
#  LabeledPoint(2.0, [22.0]),
#  LabeledPoint(2.0, [42.0]),
#  LabeledPoint(0.0, [36.0]),
#  LabeledPoint(0.0, [35.0]),
#  LabeledPoint(2.0, [98.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(1.0, [87.0]),
#  LabeledPoint(1.0, [99.0]),
#  LabeledPoint(0.0, [10.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(0.0, [25.0]),
#  LabeledPoint(0.0, [12.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(2.0, [45.0]),
#  LabeledPoint(0.0, [9.0]),
#  LabeledPoint(0.0, [16.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(0.0, [10.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(2.0, [43.0]),
#  LabeledPoint(0.0, [35.0]),
#  LabeledPoint(2.0, [28.0]),
#  LabeledPoint(1.0, [51.0]),
#  LabeledPoint(2.0, [1.0]),
#  LabeledPoint(2.0, [12.0]),
#  LabeledPoint(1.0, [77.0]),
#  LabeledPoint(1.0, [108.0]),
#  LabeledPoint(2.0, [42.0]),
#  LabeledPoint(2.0, [45.0]),
#  LabeledPoint(1.0, [83.0]),
#  LabeledPoint(0.0, [3.0]),
#  LabeledPoint(0.0, [10.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(1.0, [95.0]),
#  LabeledPoint(0.0, [7.0]),
#  LabeledPoint(2.0, [24.0]),
#  LabeledPoint(0.0, [11.0]),
#  LabeledPoint(0.0, [10.0]),
#  LabeledPoint(1.0, [50.0]),
#  LabeledPoint(1.0, [108.0]),
#  LabeledPoint(2.0, [23.0]),
#  LabeledPoint(0.0, [11.0]),
#  LabeledPoint(2.0, [22.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(1.0, [72.0]),
#  LabeledPoint(0.0, [23.0]),
#  LabeledPoint(2.0, [26.0]),
#  LabeledPoint(1.0, [84.0]),
#  LabeledPoint(2.0, [26.0]),
#  LabeledPoint(2.0, [27.0]),
#  LabeledPoint(0.0, [9.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(0.0, [28.0]),
#  LabeledPoint(1.0, [88.0]),
#  LabeledPoint(1.0, [95.0]),
#  LabeledPoint(1.0, [95.0]),
#  LabeledPoint(1.0, [138.0]),
#  LabeledPoint(1.0, [86.0]),
#  LabeledPoint(1.0, [86.0]),
#  LabeledPoint(0.0, [10.0]),
#  LabeledPoint(1.0, [84.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(2.0, [40.0]),
#  LabeledPoint(0.0, [26.0]),
#  LabeledPoint(0.0, [20.0]),
#  LabeledPoint(0.0, [10.0]),
#  LabeledPoint(1.0, [134.0]),
#  LabeledPoint(0.0, [14.0]),
#  LabeledPoint(2.0, [24.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(1.0, [95.0]),
#  LabeledPoint(2.0, [40.0]),
#  LabeledPoint(1.0, [50.0]),
#  LabeledPoint(2.0, [62.0]),
#  LabeledPoint(0.0, [3.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(1.0, [106.0]),
#  LabeledPoint(0.0, [9.0]),
#  LabeledPoint(2.0, [23.0]),
#  LabeledPoint(2.0, [42.0]),
#  LabeledPoint(0.0, [12.0]),
#  LabeledPoint(2.0, [95.0]),
#  LabeledPoint(2.0, [52.0]),
#  LabeledPoint(2.0, [43.0]),
#  LabeledPoint(2.0, [43.0]),
#  LabeledPoint(0.0, [18.0]),
#  LabeledPoint(0.0, [25.0]),
#  LabeledPoint(2.0, [49.0]),
#  LabeledPoint(1.0, [127.0]),
#  LabeledPoint(2.0, [44.0]),
#  LabeledPoint(0.0, [10.0]),
#  LabeledPoint(0.0, [11.0]),
#  LabeledPoint(0.0, [2.0]),
#  LabeledPoint(0.0, [6.0]),
#  LabeledPoint(2.0, [44.0]),
#  LabeledPoint(2.0, [45.0]),
#  LabeledPoint(2.0, [46.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(1.0, [95.0]),
#  LabeledPoint(1.0, [71.0]),
#  LabeledPoint(2.0, [43.0]),
#  LabeledPoint(2.0, [90.0]),
#  LabeledPoint(0.0, [23.0]),
#  LabeledPoint(2.0, [21.0]),
#  LabeledPoint(0.0, [17.0]),
#  LabeledPoint(2.0, [24.0]),
#  LabeledPoint(1.0, [80.0]),
#  LabeledPoint(0.0, [12.0]),
#  LabeledPoint(2.0, [20.0]),
#  LabeledPoint(0.0, [25.0]),
#  LabeledPoint(0.0, [18.0]),
#  LabeledPoint(0.0, [10.0]),
#  LabeledPoint(0.0, [15.0]),
#  LabeledPoint(0.0, [14.0]),
#  LabeledPoint(2.0, [100.0]),
#  LabeledPoint(2.0, [21.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(1.0, [95.0]),
#  LabeledPoint(0.0, [26.0]),
#  LabeledPoint(1.0, [12.0]),
#  LabeledPoint(2.0, [6.0]),
#  LabeledPoint(0.0, [5.0]),
#  LabeledPoint(2.0, [25.0]),
#  LabeledPoint(0.0, [22.0]),
#  LabeledPoint(0.0, [5.0]),
#  LabeledPoint(2.0, [43.0]),
#  LabeledPoint(1.0, [92.0]),
#  LabeledPoint(2.0, [23.0]),
#  LabeledPoint(2.0, [90.0]),
#  LabeledPoint(0.0, [14.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(1.0, [111.0]),
#  LabeledPoint(0.0, [11.0]),
#  LabeledPoint(2.0, [10.0]),
#  LabeledPoint(2.0, [24.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(0.0, [5.0]),
#  LabeledPoint(1.0, [87.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(0.0, [3.0]),
#  LabeledPoint(1.0, [110.0]),
#  LabeledPoint(2.0, [28.0]),
#  LabeledPoint(1.0, [112.0]),
#  LabeledPoint(2.0, [82.0]),
#  LabeledPoint(0.0, [17.0]),
#  LabeledPoint(1.0, [59.0]),
#  LabeledPoint(1.0, [94.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(2.0, [23.0]),
#  LabeledPoint(0.0, [20.0]),
#  LabeledPoint(2.0, [11.0]),
#  LabeledPoint(0.0, [10.0]),
#  LabeledPoint(0.0, [5.0]),
#  LabeledPoint(0.0, [11.0]),
#  LabeledPoint(2.0, [21.0]),
#  LabeledPoint(0.0, [10.0]),
#  LabeledPoint(0.0, [10.0]),
#  LabeledPoint(2.0, [47.0]),
#  LabeledPoint(2.0, [10.0]),
#  LabeledPoint(0.0, [6.0]),
#  LabeledPoint(1.0, [85.0]),
#  LabeledPoint(0.0, [23.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(1.0, [82.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(2.0, [43.0]),
#  LabeledPoint(0.0, [5.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(2.0, [42.0]),
#  LabeledPoint(2.0, [110.0]),
#  LabeledPoint(0.0, [7.0]),
#  LabeledPoint(2.0, [26.0]),
#  LabeledPoint(2.0, [23.0]),
#  LabeledPoint(2.0, [32.0]),
#  LabeledPoint(2.0, [27.0]),
#  LabeledPoint(0.0, [4.0]),
#  LabeledPoint(1.0, [64.0]),
#  LabeledPoint(0.0, [35.0]),
#  LabeledPoint(1.0, [92.0]),
#  LabeledPoint(0.0, [17.0]),
#  LabeledPoint(2.0, [21.0]),
#  LabeledPoint(0.0, [3.0]),
#  LabeledPoint(1.0, [60.0]),
#  LabeledPoint(0.0, [8.0]),
#  LabeledPoint(0.0, [15.0]),
#  LabeledPoint(2.0, [24.0]),
#  LabeledPoint(1.0, [111.0]),
#  LabeledPoint(0.0, [7.0]),
#  LabeledPoint(0.0, [28.0]),
#  LabeledPoint(1.0, [95.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(0.0, [7.0]),
#  LabeledPoint(0.0, [24.0]),
#  LabeledPoint(1.0, [92.0]),
#  LabeledPoint(1.0, [102.0]),
#  LabeledPoint(2.0, [5.0]),
#  LabeledPoint(1.0, [94.0]),
#  LabeledPoint(2.0, [14.0]),
#  LabeledPoint(2.0, [46.0]),
#  LabeledPoint(1.0, [85.0]),
#  LabeledPoint(1.0, [50.0]),
#  LabeledPoint(0.0, [2.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(2.0, [25.0]),
#  LabeledPoint(1.0, [59.0]),
#  LabeledPoint(0.0, [2.0]),
#  LabeledPoint(1.0, [70.0]),
#  LabeledPoint(2.0, [40.0]),
#  LabeledPoint(0.0, [2.0]),
#  LabeledPoint(1.0, [85.0]),
#  LabeledPoint(1.0, [89.0]),
#  LabeledPoint(2.0, [24.0]),
#  LabeledPoint(0.0, [11.0]),
#  LabeledPoint(2.0, [41.0]),
#  LabeledPoint(0.0, [35.0]),
#  LabeledPoint(0.0, [8.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(2.0, [45.0]),
#  LabeledPoint(1.0, [88.0]),
#  LabeledPoint(2.0, [53.0]),
#  LabeledPoint(2.0, [10.0]),
#  LabeledPoint(0.0, [11.0]),
#  LabeledPoint(1.0, [96.0]),
#  LabeledPoint(2.0, [22.0]),
#  LabeledPoint(1.0, [97.0]),
#  LabeledPoint(2.0, [22.0]),
#  LabeledPoint(1.0, [100.0]),
#  LabeledPoint(2.0, [52.0]),
#  LabeledPoint(1.0, [160.0]),
#  LabeledPoint(1.0, [110.0]),
#  LabeledPoint(2.0, [47.0]),
#  LabeledPoint(2.0, [15.0]),
#  LabeledPoint(0.0, [5.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(0.0, [35.0]),
#  LabeledPoint(2.0, [41.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(2.0, [12.0]),
#  LabeledPoint(2.0, [10.0]),
#  LabeledPoint(0.0, [3.0]),
#  LabeledPoint(1.0, [103.0]),
#  LabeledPoint(2.0, [3.0]),
#  LabeledPoint(2.0, [47.0]),
#  LabeledPoint(2.0, [67.0]),
#  LabeledPoint(2.0, [45.0]),
#  LabeledPoint(0.0, [27.0]),
#  LabeledPoint(0.0, [7.0]),
#  LabeledPoint(1.0, [88.0]),
#  LabeledPoint(0.0, [3.0]),
#  LabeledPoint(2.0, [16.0]),
#  LabeledPoint(0.0, [15.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(0.0, [30.0]),
#  LabeledPoint(2.0, [12.0]),
#  LabeledPoint(0.0, [10.0]),
#  LabeledPoint(0.0, [16.0]),
#  LabeledPoint(0.0, [23.0]),
#  LabeledPoint(0.0, [27.0]),
#  LabeledPoint(1.0, [165.0]),
#  LabeledPoint(0.0, [4.0]),
#  LabeledPoint(1.0, [52.0]),
#  LabeledPoint(2.0, [24.0]),
#  LabeledPoint(1.0, [35.0]),
#  LabeledPoint(2.0, [15.0]),
#  LabeledPoint(2.0, [28.0]),
#  LabeledPoint(0.0, [34.0]),
#  LabeledPoint(0.0, [14.0]),
#  LabeledPoint(2.0, [22.0]),
#  LabeledPoint(2.0, [23.0]),
#  LabeledPoint(1.0, [90.0]),
#  LabeledPoint(0.0, [5.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(1.0, [90.0]),
#  LabeledPoint(1.0, [84.0]),
#  LabeledPoint(0.0, [8.0]),
#  LabeledPoint(1.0, [89.0]),
#  LabeledPoint(2.0, [23.0]),
#  LabeledPoint(0.0, [7.0]),
#  LabeledPoint(0.0, [3.0]),
#  LabeledPoint(1.0, [89.0]),
#  LabeledPoint(0.0, [16.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(0.0, [2.0]),
#  LabeledPoint(2.0, [3.0]),
#  LabeledPoint(1.0, [84.0]),
#  LabeledPoint(2.0, [21.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(1.0, [48.0]),
#  LabeledPoint(2.0, [5.0]),
#  LabeledPoint(2.0, [42.0]),
#  LabeledPoint(2.0, [50.0]),
#  LabeledPoint(2.0, [26.0]),
#  LabeledPoint(0.0, [42.0]),
#  LabeledPoint(0.0, [2.0]),
#  LabeledPoint(2.0, [44.0]),
#  LabeledPoint(2.0, [22.0]),
#  LabeledPoint(0.0, [25.0]),
#  LabeledPoint(0.0, [18.0]),
#  LabeledPoint(1.0, [95.0]),
#  LabeledPoint(0.0, [6.0]),
#  LabeledPoint(2.0, [12.0]),
#  LabeledPoint(2.0, [24.0]),
#  LabeledPoint(2.0, [45.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(0.0, [15.0]),
#  LabeledPoint(2.0, [24.0]),
#  LabeledPoint(0.0, [14.0]),
#  LabeledPoint(1.0, [54.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(2.0, [25.0]),
#  LabeledPoint(2.0, [29.0]),
#  LabeledPoint(0.0, [2.0]),
#  LabeledPoint(2.0, [59.0]),
#  LabeledPoint(0.0, [13.0]),
#  LabeledPoint(0.0, [19.0]),
#  LabeledPoint(0.0, [17.0]),
#  LabeledPoint(1.0, [96.0]),
#  LabeledPoint(2.0, [21.0]),
#  LabeledPoint(0.0, [12.0]),
#  LabeledPoint(2.0, [21.0]),
#  LabeledPoint(2.0, [44.0]),
#  LabeledPoint(0.0, [14.0]),
#  LabeledPoint(2.0, [42.0]),
#  LabeledPoint(1.0, [110.0]),
#  LabeledPoint(0.0, [10.0]),
#  LabeledPoint(2.0, [42.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(0.0, [15.0]),
#  LabeledPoint(0.0, [18.0]),
#  LabeledPoint(0.0, [9.0]),
#  LabeledPoint(0.0, [9.0]),
#  LabeledPoint(1.0, [110.0]),
#  LabeledPoint(2.0, [43.0]),
#  LabeledPoint(1.0, [120.0]),
#  LabeledPoint(1.0, [74.0]),
#  LabeledPoint(0.0, [15.0]),
#  LabeledPoint(0.0, [10.0]),
#  LabeledPoint(2.0, [22.0]),
#  LabeledPoint(1.0, [89.0]),
#  LabeledPoint(0.0, [14.0]),
#  LabeledPoint(1.0, [13.0]),
#  LabeledPoint(1.0, [85.0]),
#  LabeledPoint(2.0, [44.0]),
#  LabeledPoint(2.0, [21.0]),
#  LabeledPoint(1.0, [78.0]),
#  LabeledPoint(2.0, [26.0]),
#  LabeledPoint(2.0, [45.0]),
#  LabeledPoint(2.0, [8.0]),
#  LabeledPoint(0.0, [15.0]),
#  LabeledPoint(0.0, [12.0]),
#  LabeledPoint(2.0, [22.0]),
#  LabeledPoint(2.0, [47.0]),
#  LabeledPoint(2.0, [28.0]),
#  LabeledPoint(1.0, [112.0]),
#  LabeledPoint(2.0, [120.0]),
#  LabeledPoint(1.0, [72.0]),
#  LabeledPoint(0.0, [18.0]),
#  LabeledPoint(2.0, [27.0]),
#  LabeledPoint(2.0, [37.0]),
#  LabeledPoint(1.0, [46.0]),
#  LabeledPoint(2.0, [43.0]),
#  LabeledPoint(1.0, [110.0]),
#  LabeledPoint(2.0, [23.0]),
#  LabeledPoint(2.0, [22.0]),
#  LabeledPoint(0.0, [21.0]),
#  LabeledPoint(0.0, [9.0]),
#  LabeledPoint(1.0, [47.0]),
#  LabeledPoint(1.0, [82.0]),
#  LabeledPoint(2.0, [3.0]),
#  LabeledPoint(2.0, [47.0]),
#  LabeledPoint(2.0, [50.0]),
#  LabeledPoint(1.0, [80.0]),
#  LabeledPoint(1.0, [100.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(1.0, [55.0]),
#  LabeledPoint(1.0, [65.0]),
#  LabeledPoint(0.0, [4.0]),
#  LabeledPoint(2.0, [49.0]),
#  LabeledPoint(0.0, [24.0]),
#  LabeledPoint(0.0, [4.0]),
#  LabeledPoint(1.0, [88.0]),
#  LabeledPoint(0.0, [10.0]),
#  LabeledPoint(2.0, [42.0]),
#  LabeledPoint(2.0, [28.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(2.0, [22.0]),
#  LabeledPoint(1.0, [83.0]),
#  LabeledPoint(0.0, [4.0]),
#  LabeledPoint(2.0, [25.0]),
#  LabeledPoint(1.0, [45.0]),
#  LabeledPoint(2.0, [26.0]),
#  LabeledPoint(0.0, [8.0]),
#  LabeledPoint(2.0, [114.0]),
#  LabeledPoint(0.0, [10.0]),
#  LabeledPoint(2.0, [22.0]),
#  LabeledPoint(0.0, [15.0]),
#  LabeledPoint(2.0, [28.0]),
#  LabeledPoint(0.0, [10.0]),
#  LabeledPoint(1.0, [89.0]),
#  LabeledPoint(2.0, [21.0]),
#  LabeledPoint(0.0, [11.0]),
#  LabeledPoint(1.0, [55.0]),
#  LabeledPoint(2.0, [5.0]),
#  LabeledPoint(2.0, [18.0]),
#  LabeledPoint(1.0, [55.0]),
#  LabeledPoint(0.0, [12.0]),
#  LabeledPoint(0.0, [15.0]),
#  LabeledPoint(0.0, [25.0]),
#  LabeledPoint(1.0, [52.0]),
#  LabeledPoint(0.0, [17.0]),
#  LabeledPoint(0.0, [7.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(2.0, [22.0]),
#  LabeledPoint(0.0, [8.0]),
#  LabeledPoint(1.0, [74.0]),
#  LabeledPoint(2.0, [53.0]),
#  LabeledPoint(1.0, [52.0]),
#  LabeledPoint(1.0, [51.0]),
#  LabeledPoint(2.0, [53.0]),
#  LabeledPoint(2.0, [21.0]),
#  LabeledPoint(0.0, [7.0]),
#  LabeledPoint(0.0, [7.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(0.0, [10.0]),
#  LabeledPoint(1.0, [57.0]),
#  LabeledPoint(0.0, [14.0]),
#  LabeledPoint(0.0, [9.0]),
#  LabeledPoint(0.0, [7.0]),
#  LabeledPoint(1.0, [67.0]),
#  LabeledPoint(2.0, [29.0]),
#  LabeledPoint(2.0, [45.0]),
#  LabeledPoint(2.0, [23.0]),
#  LabeledPoint(1.0, [72.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(0.0, [7.0]),
#  LabeledPoint(2.0, [54.0]),
#  LabeledPoint(1.0, [94.0]),
#  LabeledPoint(1.0, [97.0]),
#  LabeledPoint(0.0, [20.0]),
#  LabeledPoint(0.0, [7.0]),
#  LabeledPoint(2.0, [23.0]),
#  LabeledPoint(2.0, [55.0]),
#  LabeledPoint(0.0, [4.0]),
#  LabeledPoint(1.0, [126.0]),
#  LabeledPoint(1.0, [96.0]),
#  LabeledPoint(1.0, [93.0]),
#  LabeledPoint(2.0, [98.0]),
#  LabeledPoint(2.0, [9.0]),
#  LabeledPoint(1.0, [92.0]),
#  LabeledPoint(1.0, [94.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(0.0, [14.0]),
#  LabeledPoint(1.0, [50.0]),
#  LabeledPoint(0.0, [3.0]),
#  LabeledPoint(0.0, [4.0]),
#  LabeledPoint(2.0, [16.0]),
#  LabeledPoint(1.0, [79.0]),
#  LabeledPoint(2.0, [49.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(2.0, [22.0]),
#  LabeledPoint(2.0, [22.0]),
#  LabeledPoint(2.0, [10.0]),
#  LabeledPoint(1.0, [80.0]),
#  LabeledPoint(0.0, [7.0]),
#  LabeledPoint(1.0, [92.0]),
#  LabeledPoint(2.0, [21.0]),
#  LabeledPoint(2.0, [85.0]),
#  LabeledPoint(2.0, [21.0]),
#  LabeledPoint(2.0, [45.0]),
#  LabeledPoint(1.0, [97.0]),
#  LabeledPoint(1.0, [80.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(1.0, [100.0]),
#  LabeledPoint(1.0, [58.0]),
#  LabeledPoint(0.0, [5.0]),
#  LabeledPoint(2.0, [17.0]),
#  LabeledPoint(1.0, [92.0]),
#  LabeledPoint(1.0, [150.0]),
#  LabeledPoint(0.0, [5.0]),
#  LabeledPoint(1.0, [45.0]),
#  LabeledPoint(2.0, [22.0]),
#  LabeledPoint(2.0, [29.0]),
#  LabeledPoint(2.0, [14.0]),
#  LabeledPoint(0.0, [7.0]),
#  LabeledPoint(0.0, [10.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(0.0, [22.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(0.0, [20.0]),
#  LabeledPoint(2.0, [25.0])]

# %%
labelTestSet = []
for line in test:
    labelTestSet.append(makeTrainData(line))
labelTestSet
# Out:
# [LabeledPoint(2.0, [42.0]),
#  LabeledPoint(2.0, [13.0]),
#  LabeledPoint(2.0, [32.0]),
#  LabeledPoint(1.0, [120.0]),
#  LabeledPoint(2.0, [90.0]),
#  LabeledPoint(0.0, [27.0]),
#  LabeledPoint(1.0, [94.0]),
#  LabeledPoint(0.0, [22.0]),
#  LabeledPoint(0.0, [6.0]),
#  LabeledPoint(0.0, [5.0]),
#  LabeledPoint(2.0, [44.0]),
#  LabeledPoint(0.0, [5.0]),
#  LabeledPoint(2.0, [133.0]),
#  LabeledPoint(1.0, [87.0]),
#  LabeledPoint(0.0, [15.0]),
#  LabeledPoint(0.0, [40.0]),
#  LabeledPoint(0.0, [5.0]),
#  LabeledPoint(2.0, [37.0]),
#  LabeledPoint(2.0, [22.0]),
#  LabeledPoint(0.0, [6.0]),
#  LabeledPoint(0.0, [16.0]),
#  LabeledPoint(1.0, [128.0]),
#  LabeledPoint(0.0, [22.0]),
#  LabeledPoint(2.0, [41.0]),
#  LabeledPoint(2.0, [86.0]),
#  LabeledPoint(2.0, [11.0]),
#  LabeledPoint(1.0, [59.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(0.0, [25.0]),
#  LabeledPoint(2.0, [21.0]),
#  LabeledPoint(2.0, [25.0]),
#  LabeledPoint(0.0, [5.0]),
#  LabeledPoint(2.0, [45.0]),
#  LabeledPoint(2.0, [43.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(2.0, [43.0]),
#  LabeledPoint(2.0, [48.0]),
#  LabeledPoint(1.0, [69.0]),
#  LabeledPoint(1.0, [90.0]),
#  LabeledPoint(2.0, [50.0]),
#  LabeledPoint(0.0, [1.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(0.0, [6.0]),
#  LabeledPoint(1.0, [87.0]),
#  LabeledPoint(2.0, [47.0]),
#  LabeledPoint(2.0, [13.0]),
#  LabeledPoint(1.0, [90.0]),
#  LabeledPoint(0.0, [6.0]),
#  LabeledPoint(1.0, [85.0]),
#  LabeledPoint(1.0, [107.0]),
#  LabeledPoint(0.0, [14.0]),
#  LabeledPoint(0.0, [28.0]),
#  LabeledPoint(2.0, [12.0]),
#  LabeledPoint(1.0, [119.0]),
#  LabeledPoint(0.0, [19.0]),
#  LabeledPoint(2.0, [52.0]),
#  LabeledPoint(2.0, [50.0]),
#  LabeledPoint(0.0, [15.0]),
#  LabeledPoint(2.0, [41.0]),
#  LabeledPoint(1.0, [77.0]),
#  LabeledPoint(2.0, [42.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(0.0, [3.0]),
#  LabeledPoint(0.0, [17.0]),
#  LabeledPoint(1.0, [89.0]),
#  LabeledPoint(0.0, [10.0]),
#  LabeledPoint(0.0, [6.0]),
#  LabeledPoint(2.0, [45.0]),
#  LabeledPoint(2.0, [24.0]),
#  LabeledPoint(1.0, [53.0]),
#  LabeledPoint(0.0, [6.0]),
#  LabeledPoint(0.0, [12.0]),
#  LabeledPoint(2.0, [42.0]),
#  LabeledPoint(0.0, [20.0]),
#  LabeledPoint(1.0, [98.0]),
#  LabeledPoint(2.0, [22.0]),
#  LabeledPoint(1.0, [93.0]),
#  LabeledPoint(1.0, [88.0]),
#  LabeledPoint(0.0, [11.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(2.0, [43.0]),
#  LabeledPoint(1.0, [92.0]),
#  LabeledPoint(2.0, [107.0]),
#  LabeledPoint(0.0, [5.0]),
#  LabeledPoint(2.0, [14.0]),
#  LabeledPoint(1.0, [60.0]),
#  LabeledPoint(2.0, [44.0]),
#  LabeledPoint(2.0, [45.0]),
#  LabeledPoint(0.0, [25.0]),
#  LabeledPoint(0.0, [3.0]),
#  LabeledPoint(0.0, [9.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(1.0, [95.0]),
#  LabeledPoint(0.0, [15.0]),
#  LabeledPoint(1.0, [90.0]),
#  LabeledPoint(1.0, [77.0]),
#  LabeledPoint(1.0, [100.0]),
#  LabeledPoint(2.0, [16.0]),
#  LabeledPoint(0.0, [9.0]),
#  LabeledPoint(2.0, [23.0]),
#  LabeledPoint(2.0, [41.0]),
#  LabeledPoint(1.0, [91.0]),
#  LabeledPoint(0.0, [13.0]),
#  LabeledPoint(0.0, [12.0]),
#  LabeledPoint(1.0, [100.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(0.0, [25.0]),
#  LabeledPoint(2.0, [11.0]),
#  LabeledPoint(2.0, [221.0]),
#  LabeledPoint(2.0, [43.0]),
#  LabeledPoint(0.0, [1.0]),
#  LabeledPoint(2.0, [57.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(0.0, [26.0]),
#  LabeledPoint(2.0, [24.0]),
#  LabeledPoint(2.0, [40.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(1.0, [143.0]),
#  LabeledPoint(2.0, [26.0]),
#  LabeledPoint(2.0, [54.0]),
#  LabeledPoint(2.0, [24.0]),
#  LabeledPoint(0.0, [15.0]),
#  LabeledPoint(2.0, [35.0]),
#  LabeledPoint(2.0, [44.0]),
#  LabeledPoint(1.0, [90.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(2.0, [22.0]),
#  LabeledPoint(0.0, [10.0]),
#  LabeledPoint(1.0, [92.0]),
#  LabeledPoint(0.0, [6.0]),
#  LabeledPoint(1.0, [81.0]),
#  LabeledPoint(1.0, [35.0]),
#  LabeledPoint(1.0, [61.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(1.0, [71.0]),
#  LabeledPoint(0.0, [37.0]),
#  LabeledPoint(0.0, [3.0]),
#  LabeledPoint(1.0, [192.0]),
#  LabeledPoint(2.0, [44.0]),
#  LabeledPoint(1.0, [80.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(1.0, [46.0]),
#  LabeledPoint(2.0, [21.0]),
#  LabeledPoint(1.0, [86.0]),
#  LabeledPoint(0.0, [28.0]),
#  LabeledPoint(1.0, [91.0]),
#  LabeledPoint(0.0, [2.0]),
#  LabeledPoint(1.0, [90.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(0.0, [15.0]),
#  LabeledPoint(1.0, [89.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(2.0, [22.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(2.0, [34.0]),
#  LabeledPoint(2.0, [40.0]),
#  LabeledPoint(0.0, [5.0]),
#  LabeledPoint(2.0, [53.0]),
#  LabeledPoint(0.0, [15.0]),
#  LabeledPoint(1.0, [98.0]),
#  LabeledPoint(1.0, [73.0]),
#  LabeledPoint(0.0, [8.0]),
#  LabeledPoint(2.0, [19.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(1.0, [60.0]),
#  LabeledPoint(1.0, [90.0]),
#  LabeledPoint(0.0, [4.0]),
#  LabeledPoint(2.0, [21.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(1.0, [120.0]),
#  LabeledPoint(0.0, [25.0]),
#  LabeledPoint(0.0, [22.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(0.0, [20.0]),
#  LabeledPoint(1.0, [116.0]),
#  LabeledPoint(0.0, [6.0]),
#  LabeledPoint(1.0, [55.0]),
#  LabeledPoint(2.0, [180.0]),
#  LabeledPoint(1.0, [55.0]),
#  LabeledPoint(0.0, [23.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(2.0, [23.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(1.0, [98.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(1.0, [130.0]),
#  LabeledPoint(2.0, [45.0]),
#  LabeledPoint(2.0, [29.0]),
#  LabeledPoint(0.0, [13.0]),
#  LabeledPoint(0.0, [15.0]),
#  LabeledPoint(0.0, [7.0]),
#  LabeledPoint(1.0, [90.0]),
#  LabeledPoint(2.0, [22.0]),
#  LabeledPoint(1.0, [92.0]),
#  LabeledPoint(0.0, [8.0]),
#  LabeledPoint(2.0, [22.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(2.0, [39.0]),
#  LabeledPoint(1.0, [89.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(1.0, [93.0]),
#  LabeledPoint(2.0, [23.0]),
#  LabeledPoint(0.0, [9.0]),
#  LabeledPoint(1.0, [94.0]),
#  LabeledPoint(1.0, [100.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(1.0, [90.0]),
#  LabeledPoint(0.0, [9.0]),
#  LabeledPoint(2.0, [45.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(1.0, [100.0]),
#  LabeledPoint(0.0, [16.0]),
#  LabeledPoint(0.0, [15.0]),
#  LabeledPoint(2.0, [43.0]),
#  LabeledPoint(0.0, [3.0]),
#  LabeledPoint(1.0, [64.0]),
#  LabeledPoint(0.0, [15.0]),
#  LabeledPoint(1.0, [162.0]),
#  LabeledPoint(1.0, [47.0]),
#  LabeledPoint(1.0, [52.0]),
#  LabeledPoint(2.0, [42.0]),
#  LabeledPoint(1.0, [105.0]),
#  LabeledPoint(2.0, [90.0]),
#  LabeledPoint(0.0, [5.0]),
#  LabeledPoint(2.0, [272.0]),
#  LabeledPoint(0.0, [3.0]),
#  LabeledPoint(2.0, [25.0]),
#  LabeledPoint(0.0, [13.0]),
#  LabeledPoint(1.0, [85.0]),
#  LabeledPoint(0.0, [11.0]),
#  LabeledPoint(2.0, [47.0]),
#  LabeledPoint(0.0, [6.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(0.0, [3.0]),
#  LabeledPoint(2.0, [43.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(1.0, [76.0]),
#  LabeledPoint(2.0, [26.0]),
#  LabeledPoint(1.0, [52.0]),
#  LabeledPoint(2.0, [23.0]),
#  LabeledPoint(1.0, [128.0]),
#  LabeledPoint(2.0, [22.0]),
#  LabeledPoint(0.0, [7.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(0.0, [15.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(2.0, [50.0]),
#  LabeledPoint(1.0, [84.0]),
#  LabeledPoint(0.0, [26.0]),
#  LabeledPoint(1.0, [56.0]),
#  LabeledPoint(1.0, [148.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(0.0, [39.0]),
#  LabeledPoint(0.0, [13.0]),
#  LabeledPoint(0.0, [21.0]),
#  LabeledPoint(2.0, [210.0]),
#  LabeledPoint(2.0, [23.0]),
#  LabeledPoint(1.0, [95.0]),
#  LabeledPoint(2.0, [8.0]),
#  LabeledPoint(2.0, [26.0]),
#  LabeledPoint(0.0, [15.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(0.0, [17.0]),
#  LabeledPoint(0.0, [17.0]),
#  LabeledPoint(1.0, [111.0]),
#  LabeledPoint(0.0, [10.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(0.0, [7.0]),
#  LabeledPoint(2.0, [59.0]),
#  LabeledPoint(0.0, [3.0]),
#  LabeledPoint(2.0, [125.0]),
#  LabeledPoint(2.0, [43.0]),
#  LabeledPoint(2.0, [14.0]),
#  LabeledPoint(0.0, [8.0]),
#  LabeledPoint(1.0, [90.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(1.0, [135.0]),
#  LabeledPoint(2.0, [24.0]),
#  LabeledPoint(2.0, [22.0]),
#  LabeledPoint(2.0, [73.0]),
#  LabeledPoint(0.0, [2.0]),
#  LabeledPoint(1.0, [60.0]),
#  LabeledPoint(2.0, [42.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(2.0, [7.0]),
#  LabeledPoint(2.0, [41.0]),
#  LabeledPoint(2.0, [40.0]),
#  LabeledPoint(1.0, [100.0]),
#  LabeledPoint(1.0, [90.0]),
#  LabeledPoint(0.0, [6.0]),
#  LabeledPoint(2.0, [23.0]),
#  LabeledPoint(0.0, [12.0]),
#  LabeledPoint(1.0, [160.0]),
#  LabeledPoint(0.0, [13.0]),
#  LabeledPoint(2.0, [110.0]),
#  LabeledPoint(2.0, [47.0]),
#  LabeledPoint(1.0, [90.0]),
#  LabeledPoint(2.0, [5.0]),
#  LabeledPoint(0.0, [4.0]),
#  LabeledPoint(0.0, [10.0]),
#  LabeledPoint(2.0, [11.0]),
#  LabeledPoint(1.0, [60.0]),
#  LabeledPoint(2.0, [47.0]),
#  LabeledPoint(1.0, [67.0]),
#  LabeledPoint(2.0, [15.0]),
#  LabeledPoint(1.0, [76.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(1.0, [84.0]),
#  LabeledPoint(2.0, [25.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(0.0, [9.0]),
#  LabeledPoint(2.0, [13.0]),
#  LabeledPoint(2.0, [52.0]),
#  LabeledPoint(2.0, [25.0]),
#  LabeledPoint(0.0, [11.0]),
#  LabeledPoint(1.0, [70.0]),
#  LabeledPoint(1.0, [52.0]),
#  LabeledPoint(0.0, [7.0]),
#  LabeledPoint(0.0, [26.0]),
#  LabeledPoint(0.0, [4.0]),
#  LabeledPoint(2.0, [26.0]),
#  LabeledPoint(0.0, [15.0]),
#  LabeledPoint(2.0, [44.0]),
#  LabeledPoint(1.0, [60.0]),
#  LabeledPoint(2.0, [22.0]),
#  LabeledPoint(0.0, [3.0]),
#  LabeledPoint(1.0, [71.0]),
#  LabeledPoint(2.0, [28.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(2.0, [42.0]),
#  LabeledPoint(0.0, [4.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(0.0, [9.0]),
#  LabeledPoint(2.0, [23.0]),
#  LabeledPoint(2.0, [67.0]),
#  LabeledPoint(2.0, [6.0]),
#  LabeledPoint(2.0, [44.0]),
#  LabeledPoint(2.0, [45.0]),
#  LabeledPoint(2.0, [15.0]),
#  LabeledPoint(0.0, [28.0]),
#  LabeledPoint(0.0, [10.0]),
#  LabeledPoint(2.0, [43.0]),
#  LabeledPoint(2.0, [43.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(2.0, [8.0]),
#  LabeledPoint(0.0, [4.0]),
#  LabeledPoint(0.0, [15.0]),
#  LabeledPoint(2.0, [15.0]),
#  LabeledPoint(0.0, [10.0]),
#  LabeledPoint(0.0, [5.0]),
#  LabeledPoint(0.0, [9.0]),
#  LabeledPoint(1.0, [97.0]),
#  LabeledPoint(2.0, [41.0]),
#  LabeledPoint(2.0, [25.0]),
#  LabeledPoint(2.0, [23.0]),
#  LabeledPoint(0.0, [25.0]),
#  LabeledPoint(2.0, [18.0]),
#  LabeledPoint(2.0, [23.0]),
#  LabeledPoint(0.0, [10.0]),
#  LabeledPoint(0.0, [27.0]),
#  LabeledPoint(2.0, [6.0]),
#  LabeledPoint(2.0, [22.0]),
#  LabeledPoint(1.0, [90.0]),
#  LabeledPoint(0.0, [6.0]),
#  LabeledPoint(2.0, [25.0]),
#  LabeledPoint(1.0, [94.0]),
#  LabeledPoint(2.0, [67.0]),
#  LabeledPoint(2.0, [64.0]),
#  LabeledPoint(1.0, [125.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(1.0, [104.0]),
#  LabeledPoint(1.0, [83.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(2.0, [22.0]),
#  LabeledPoint(2.0, [43.0]),
#  LabeledPoint(2.0, [21.0]),
#  LabeledPoint(1.0, [80.0]),
#  LabeledPoint(2.0, [23.0]),
#  LabeledPoint(1.0, [108.0]),
#  LabeledPoint(0.0, [11.0]),
#  LabeledPoint(1.0, [46.0]),
#  LabeledPoint(0.0, [3.0]),
#  LabeledPoint(1.0, [67.0]),
#  LabeledPoint(0.0, [28.0]),
#  LabeledPoint(0.0, [12.0]),
#  LabeledPoint(0.0, [14.0]),
#  LabeledPoint(1.0, [81.0]),
#  LabeledPoint(1.0, [62.0]),
#  LabeledPoint(0.0, [10.0]),
#  LabeledPoint(2.0, [15.0]),
#  LabeledPoint(0.0, [13.0]),
#  LabeledPoint(1.0, [80.0]),
#  LabeledPoint(1.0, [114.0]),
#  LabeledPoint(0.0, [2.0]),
#  LabeledPoint(0.0, [43.0]),
#  LabeledPoint(2.0, [23.0]),
#  LabeledPoint(1.0, [105.0]),
#  LabeledPoint(1.0, [79.0]),
#  LabeledPoint(0.0, [18.0]),
#  LabeledPoint(1.0, [127.0]),
#  LabeledPoint(1.0, [107.0]),
#  LabeledPoint(0.0, [14.0]),
#  LabeledPoint(2.0, [32.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(2.0, [22.0]),
#  LabeledPoint(0.0, [8.0]),
#  LabeledPoint(0.0, [2.0]),
#  LabeledPoint(2.0, [51.0]),
#  LabeledPoint(2.0, [100.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(2.0, [46.0]),
#  LabeledPoint(0.0, [8.0]),
#  LabeledPoint(0.0, [22.0]),
#  LabeledPoint(2.0, [45.0]),
#  LabeledPoint(2.0, [25.0]),
#  LabeledPoint(0.0, [6.0]),
#  LabeledPoint(2.0, [22.0]),
#  LabeledPoint(2.0, [23.0]),
#  LabeledPoint(2.0, [29.0]),
#  LabeledPoint(2.0, [45.0]),
#  LabeledPoint(1.0, [108.0]),
#  LabeledPoint(0.0, [6.0]),
#  LabeledPoint(1.0, [134.0]),
#  LabeledPoint(2.0, [23.0]),
#  LabeledPoint(1.0, [97.0]),
#  LabeledPoint(2.0, [21.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(0.0, [22.0]),
#  LabeledPoint(0.0, [7.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(1.0, [82.0]),
#  LabeledPoint(2.0, [44.0]),
#  LabeledPoint(2.0, [6.0]),
#  LabeledPoint(2.0, [60.0]),
#  LabeledPoint(1.0, [109.0]),
#  LabeledPoint(2.0, [21.0]),
#  LabeledPoint(0.0, [11.0]),
#  LabeledPoint(0.0, [1.0]),
#  LabeledPoint(2.0, [22.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(1.0, [76.0]),
#  LabeledPoint(0.0, [11.0]),
#  LabeledPoint(0.0, [5.0]),
#  LabeledPoint(0.0, [3.0]),
#  LabeledPoint(1.0, [60.0]),
#  LabeledPoint(1.0, [96.0]),
#  LabeledPoint(2.0, [54.0]),
#  LabeledPoint(2.0, [42.0]),
#  LabeledPoint(2.0, [44.0]),
#  LabeledPoint(2.0, [43.0]),
#  LabeledPoint(0.0, [30.0]),
#  LabeledPoint(2.0, [24.0]),
#  LabeledPoint(2.0, [25.0]),
#  LabeledPoint(2.0, [24.0]),
#  LabeledPoint(0.0, [10.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(2.0, [44.0]),
#  LabeledPoint(2.0, [43.0]),
#  LabeledPoint(1.0, [120.0]),
#  LabeledPoint(2.0, [25.0]),
#  LabeledPoint(1.0, [54.0]),
#  LabeledPoint(0.0, [8.0]),
#  LabeledPoint(0.0, [5.0]),
#  LabeledPoint(1.0, [125.0]),
#  LabeledPoint(0.0, [6.0]),
#  LabeledPoint(2.0, [23.0]),
#  LabeledPoint(0.0, [27.0]),
#  LabeledPoint(2.0, [44.0]),
#  LabeledPoint(0.0, [3.0]),
#  LabeledPoint(2.0, [15.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(0.0, [18.0]),
#  LabeledPoint(1.0, [51.0]),
#  LabeledPoint(0.0, [6.0]),
#  LabeledPoint(1.0, [155.0]),
#  LabeledPoint(0.0, [7.0]),
#  LabeledPoint(1.0, [70.0]),
#  LabeledPoint(2.0, [43.0]),
#  LabeledPoint(2.0, [43.0]),
#  LabeledPoint(1.0, [84.0]),
#  LabeledPoint(2.0, [24.0]),
#  LabeledPoint(2.0, [70.0]),
#  LabeledPoint(2.0, [21.0]),
#  LabeledPoint(2.0, [3.0]),
#  LabeledPoint(2.0, [23.0]),
#  LabeledPoint(2.0, [23.0]),
#  LabeledPoint(1.0, [83.0]),
#  LabeledPoint(0.0, [11.0]),
#  LabeledPoint(2.0, [22.0]),
#  LabeledPoint(1.0, [123.0]),
#  LabeledPoint(2.0, [5.0]),
#  LabeledPoint(2.0, [23.0]),
#  LabeledPoint(2.0, [44.0]),
#  LabeledPoint(0.0, [22.0]),
#  LabeledPoint(1.0, [61.0])]

# %%
# Train a naive Bayes model.
trainSetRDD = sc.parallelize(labelTrainSet)
testSetRDD = sc.parallelize(labelTestSet)

trainSetRDD.take(30)
# Out:
# [LabeledPoint(1.0, [78.0]),
#  LabeledPoint(1.0, [47.0]),
#  LabeledPoint(1.0, [79.0]),
#  LabeledPoint(0.0, [5.0]),
#  LabeledPoint(1.0, [96.0]),
#  LabeledPoint(0.0, [13.0]),
#  LabeledPoint(0.0, [16.0]),
#  LabeledPoint(1.0, [86.0]),
#  LabeledPoint(0.0, [1.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(0.0, [13.0]),
#  LabeledPoint(2.0, [3.0]),
#  LabeledPoint(0.0, [27.0]),
#  LabeledPoint(2.0, [15.0]),
#  LabeledPoint(2.0, [52.0]),
#  LabeledPoint(2.0, [100.0]),
#  LabeledPoint(2.0, [23.0]),
#  LabeledPoint(2.0, [22.0]),
#  LabeledPoint(2.0, [30.0]),
#  LabeledPoint(0.0, [10.0]),
#  LabeledPoint(0.0, [32.0]),
#  LabeledPoint(2.0, [115.0]),
#  LabeledPoint(1.0, [91.0]),
#  LabeledPoint(2.0, [43.0]),
#  LabeledPoint(2.0, [41.0]),
#  LabeledPoint(1.0, [51.0]),
#  LabeledPoint(1.0, [50.0]),
#  LabeledPoint(0.0, [21.0]),
#  LabeledPoint(1.0, [66.0]),
#  LabeledPoint(0.0, [13.0])]

# %%
import pandas
from pandas.plotting import scatter_matrix

# %%
N = len(x)
x = x
y = y
colors = numpy.random.rand(N)
area = (40 * numpy.random.rand(N))**2  # 0 to 15 point radii

plt.scatter(x, y, s=area, c=colors, alpha=0.5)
plt.show()

# %%
from pyspark.mllib.tree import DecisionTree, DecisionTreeModel
# Train a DecisionTree model.
#  Empty categoricalFeaturesInfo indicates all features are continuous.
model = DecisionTree.trainClassifier(trainSetRDD, numClasses=3, categoricalFeaturesInfo={},
                                 impurity='entropy')

# Evaluate model on test instances and compute test error
predictions = model.predict(testSetRDD.map(lambda x: x.features))
labelsAndPredictions = testSetRDD.map(lambda lp: lp.label).zip(predictions)
testErr = labelsAndPredictions.filter(lambda p:p[0]!=p[1]).count() / float(testSetRDD.count())
accuracy = labelsAndPredictions.filter(lambda p:p[0]==p[1]).count() / float(testSetRDD.count())
print('Test Error = ' + str(testErr))
print('Accuracy= ' + str(accuracy) )
print('Learned classification tree model:')
print(model.toDebugString())

# Save and load model
model.save(sc, "/home/prakass1/myDecisionTreeClassificationModel")
sameModel = DecisionTreeModel.load(sc, "/home/prakass1/myDecisionTreeClassificationModel")
# Out:
# Test Error = 0.19
# Accuracy= 0.81
# Learned classification tree model:
# DecisionTreeModel classifier of depth 5 with 47 nodes
#   If (feature 0 <= 44.5)
#    If (feature 0 <= 20.5)
#     If (feature 0 <= 10.5)
#      If (feature 0 <= 6.5)
#       If (feature 0 <= 4.5)
#        Predict: 0.0
#       Else (feature 0 > 4.5)
#        Predict: 0.0
#      Else (feature 0 > 6.5)
#       If (feature 0 <= 9.5)
#        Predict: 0.0
#       Else (feature 0 > 9.5)
#        Predict: 0.0
#     Else (feature 0 > 10.5)
#      If (feature 0 <= 14.5)
#       If (feature 0 <= 12.5)
#        Predict: 0.0
#       Else (feature 0 > 12.5)
#        Predict: 0.0
#      Else (feature 0 > 14.5)
#       If (feature 0 <= 15.5)
#        Predict: 0.0
#       Else (feature 0 > 15.5)
#        Predict: 0.0
#    Else (feature 0 > 20.5)
#     If (feature 0 <= 41.5)
#      If (feature 0 <= 31.0)
#       If (feature 0 <= 29.5)
#        Predict: 2.0
#       Else (feature 0 > 29.5)
#        Predict: 2.0
#      Else (feature 0 > 31.0)
#       If (feature 0 <= 33.0)
#        Predict: 0.0
#       Else (feature 0 > 33.0)
#        Predict: 2.0
#     Else (feature 0 > 41.5)
#      If (feature 0 <= 43.5)
#       Predict: 2.0
#      Else (feature 0 > 43.5)
#       Predict: 2.0
#   Else (feature 0 > 44.5)
#    If (feature 0 <= 63.5)
#     If (feature 0 <= 59.5)
#      If (feature 0 <= 48.5)
#       Predict: 2.0
#      Else (feature 0 > 48.5)
#       If (feature 0 <= 53.5)
#        Predict: 2.0
#       Else (feature 0 > 53.5)
#        Predict: 1.0
#     Else (feature 0 > 59.5)
#      Predict: 2.0
#    Else (feature 0 > 63.5)
#     If (feature 0 <= 99.5)
#      If (feature 0 <= 89.5)
#       If (feature 0 <= 84.5)
#        Predict: 1.0
#       Else (feature 0 > 84.5)
#        Predict: 1.0
#      Else (feature 0 > 89.5)
#       If (feature 0 <= 93.5)
#        Predict: 1.0
#       Else (feature 0 > 93.5)
#        Predict: 1.0
#     Else (feature 0 > 99.5)
#      If (feature 0 <= 111.5)
#       Predict: 1.0
#      Else (feature 0 > 111.5)
#       Predict: 1.0
# ---------------------------------------------------------------------------
# Py4JJavaError                             Traceback (most recent call last)
# <ipython-input-96-c368de34b959> in <module>()
#      16
#      17 # Save and load model
# ---> 18 model.save(sc, "/home/prakass1/myDecisionTreeClassificationModel")
#      19 sameModel = DecisionTreeModel.load(sc, "/home/prakass1/myDecisionTreeClassificationModel")
#
# /usr/local/spark/python/pyspark/mllib/util.py in save(self, sc, path)
#     404         if not isinstance(path, basestring):
#     405             raise TypeError("path should be a basestring, got type %s" % type(path))
# --> 406         self._java_model.save(sc._jsc.sc(), path)
#     407
#     408
#
# /usr/local/spark/python/lib/py4j-0.10.6-src.zip/py4j/java_gateway.py in __call__(self, *args)
#    1158         answer = self.gateway_client.send_command(command)
#    1159         return_value = get_return_value(
# -> 1160             answer, self.gateway_client, self.target_id, self.name)
#    1161
#    1162         for temp_arg in temp_args:
#
# /usr/local/spark/python/pyspark/sql/utils.py in deco(*a, **kw)
#      61     def deco(*a, **kw):
#      62         try:
# ---> 63             return f(*a, **kw)
#      64         except py4j.protocol.Py4JJavaError as e:
#      65             s = e.java_exception.toString()
#
# /usr/local/spark/python/lib/py4j-0.10.6-src.zip/py4j/protocol.py in get_return_value(answer, gateway_client, target_id, name)
#     318                 raise Py4JJavaError(
#     319                     "An error occurred while calling {0}{1}{2}.\n".
# --> 320                     format(target_id, ".", name), value)
#     321             else:
#     322                 raise Py4JError(
#
# Py4JJavaError: An error occurred while calling o736.save.
# : org.apache.hadoop.mapred.FileAlreadyExistsException: Output directory file:/home/prakass1/myDecisionTreeClassificationModel/metadata already exists
# 	at org.apache.hadoop.mapred.FileOutputFormat.checkOutputSpecs(FileOutputFormat.java:131)
# 	at org.apache.spark.internal.io.HadoopMapRedWriteConfigUtil.assertConf(SparkHadoopWriter.scala:283)
# 	at org.apache.spark.internal.io.SparkHadoopWriter$.write(SparkHadoopWriter.scala:71)
# 	at org.apache.spark.rdd.PairRDDFunctions$$anonfun$saveAsHadoopDataset$1.apply$mcV$sp(PairRDDFunctions.scala:1096)
# 	at org.apache.spark.rdd.PairRDDFunctions$$anonfun$saveAsHadoopDataset$1.apply(PairRDDFunctions.scala:1094)
# 	at org.apache.spark.rdd.PairRDDFunctions$$anonfun$saveAsHadoopDataset$1.apply(PairRDDFunctions.scala:1094)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:151)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:112)
# 	at org.apache.spark.rdd.RDD.withScope(RDD.scala:363)
# 	at org.apache.spark.rdd.PairRDDFunctions.saveAsHadoopDataset(PairRDDFunctions.scala:1094)
# 	at org.apache.spark.rdd.PairRDDFunctions$$anonfun$saveAsHadoopFile$4.apply$mcV$sp(PairRDDFunctions.scala:1067)
# 	at org.apache.spark.rdd.PairRDDFunctions$$anonfun$saveAsHadoopFile$4.apply(PairRDDFunctions.scala:1032)
# 	at org.apache.spark.rdd.PairRDDFunctions$$anonfun$saveAsHadoopFile$4.apply(PairRDDFunctions.scala:1032)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:151)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:112)
# 	at org.apache.spark.rdd.RDD.withScope(RDD.scala:363)
# 	at org.apache.spark.rdd.PairRDDFunctions.saveAsHadoopFile(PairRDDFunctions.scala:1032)
# 	at org.apache.spark.rdd.PairRDDFunctions$$anonfun$saveAsHadoopFile$1.apply$mcV$sp(PairRDDFunctions.scala:958)
# 	at org.apache.spark.rdd.PairRDDFunctions$$anonfun$saveAsHadoopFile$1.apply(PairRDDFunctions.scala:958)
# 	at org.apache.spark.rdd.PairRDDFunctions$$anonfun$saveAsHadoopFile$1.apply(PairRDDFunctions.scala:958)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:151)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:112)
# 	at org.apache.spark.rdd.RDD.withScope(RDD.scala:363)
# 	at org.apache.spark.rdd.PairRDDFunctions.saveAsHadoopFile(PairRDDFunctions.scala:957)
# 	at org.apache.spark.rdd.RDD$$anonfun$saveAsTextFile$1.apply$mcV$sp(RDD.scala:1493)
# 	at org.apache.spark.rdd.RDD$$anonfun$saveAsTextFile$1.apply(RDD.scala:1472)
# 	at org.apache.spark.rdd.RDD$$anonfun$saveAsTextFile$1.apply(RDD.scala:1472)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:151)
# 	at org.apache.spark.rdd.RDDOperationScope$.withScope(RDDOperationScope.scala:112)
# 	at org.apache.spark.rdd.RDD.withScope(RDD.scala:363)
# 	at org.apache.spark.rdd.RDD.saveAsTextFile(RDD.scala:1472)
# 	at org.apache.spark.mllib.tree.model.DecisionTreeModel$SaveLoadV1_0$.save(DecisionTreeModel.scala:231)
# 	at org.apache.spark.mllib.tree.model.DecisionTreeModel.save(DecisionTreeModel.scala:127)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke0(Native Method)
# 	at sun.reflect.NativeMethodAccessorImpl.invoke(NativeMethodAccessorImpl.java:62)
# 	at sun.reflect.DelegatingMethodAccessorImpl.invoke(DelegatingMethodAccessorImpl.java:43)
# 	at java.lang.reflect.Method.invoke(Method.java:498)
# 	at py4j.reflection.MethodInvoker.invoke(MethodInvoker.java:244)
# 	at py4j.reflection.ReflectionEngine.invoke(ReflectionEngine.java:357)
# 	at py4j.Gateway.invoke(Gateway.java:282)
# 	at py4j.commands.AbstractCommand.invokeMethod(AbstractCommand.java:132)
# 	at py4j.commands.CallCommand.execute(CallCommand.java:79)
# 	at py4j.GatewayConnection.run(GatewayConnection.java:214)
# 	at java.lang.Thread.run(Thread.java:748)

# %%
val = int(model.predict([110.0]))
label = getLabelVal(val,flag=True)
val,label
# Out:
# (1, 'movie')

# %%
val = int(model.predict([20.0]))
label = getLabelVal(val,flag=True)
val,label
# Out:
# (0, 'short')

# %%
val = int(model.predict([25.0]))
label = getLabelVal(val,flag=True)
val,label
# Out:
# (2, 'tvEpisode')

# %%
#sc.stop()
